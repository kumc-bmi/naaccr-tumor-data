# %% [markdown]
# # NAACCR Tumor Registry Data
#
# This is both a notebook and a module, sync'd using [jupytext][]. See also
#
#   - README for motivation and usage
#   - CONTRIBUTING for coding style etc.
#     - Note especially **ISSUE**, **TODO** and **IDEA** markers
#
# [jupytext]: https://github.com/mwouts/jupytext

# %% [markdown]
# ### Preface: PyData Tools: Pandas, PySpark

# %%
# python stdlib
from gzip import GzipFile
from importlib import resources as res
from pathlib import Path as Path_T
from sys import stderr
from typing import ContextManager, Dict, Iterator, List, NoReturn
from typing import Optional as Opt, Union, cast
from xml.etree import ElementTree as XML
import logging

# %%
# 3rd party code: PyData
from pyspark.sql import SparkSession as SparkSession_T, Window
from pyspark.sql import types as ty, functions as func
from pyspark.sql.dataframe import DataFrame
from pyspark import sql as sq
import numpy as np   # type: ignore
import pandas as pd  # type: ignore

# %%
# 3rd party: naaccr-xml
import naaccr_xml_samples

import bc_qa

# %%
# this project
from sql_script import SqlScript
from tumor_reg_ont import NAACCR1, NAACCR_Layout, LOINC_NAACCR, NAACCR_R, NAACCR_I2B2
from tumor_reg_ont import create_objects, ddictDF, eltSchema, xmlDF, eltDict
import heron_load

# %%
log = logging.getLogger(__name__)

if __name__ == '__main__' or True:
    logging.basicConfig(level=logging.INFO, stream=stderr)
    log.info('NAACCR exploration...')
# Out:
# INFO:__main__:NAACCR exploration...

# %%
log.info('%s', dict(pandas=pd.__version__))
# Out:
# INFO:__main__:{'pandas': '0.24.2'}

# %% [markdown]
# ## I/O Access: local files, Spark / Hive metastore

# %% [markdown]
# In a notebook context, we have `__name__ == '__main__'`.
#
# Otherwise, we maintain ocap discipline (see CONTRIBUTING)
# and don't import powerful objects.

# %% [markdown]
#  - **TODO/WIP**: use `_spark` and `_cwd`; i.e. be sure not to "export" ambient authority.

# %%
IO_TESTING = __name__ == '__main__'
_spark = cast(SparkSession_T, None)
if IO_TESTING:
    if 'spark' in globals():
        _spark = spark  # type: ignore  # noqa
        del spark       # type: ignore
    else:
        def _make_spark_session(appName: str = "tumor_reg_data") -> SparkSession_T:
            """
            ref:
            https://spark.apache.org/docs/latest/sql-getting-started.html
            """
            from pyspark.sql import SparkSession

            return SparkSession \
                .builder \
                .appName(appName) \
                .getOrCreate()
        _spark = _make_spark_session()

    def _get_cwd() -> Path_T:
        # ISSUE: ambient
        from pathlib import Path
        return Path('.')

    _cwd = _get_cwd()
    log.info('cwd: %s', _cwd.resolve())
# Out:
# INFO:__main__:cwd: /home/dconnolly/projects/naaccr-tumor-data/notebooks

# %% [markdown]
# The `spark` global is available when we launch as
# `PYSPARK_DRIVER_PYTHON=jupyter PYSPARK_DRIVER_PYTHON_OPTS=notebook
#    pyspark ...`.

# %%
IO_TESTING and _spark


def quiet_logs(spark: SparkSession_T) -> None:
    sc = spark.sparkContext
    # ack: FDS Aug 2015 https://stackoverflow.com/a/32208445
    logger = sc._jvm.org.apache.log4j  # type: ignore
    logger.LogManager.getLogger("org"). setLevel(logger.Level.WARN)
    logger.LogManager.getLogger("akka").setLevel(logger.Level.WARN)

# %%
if IO_TESTING:
    log.info('spark web UI: %s', _spark.sparkContext.uiWebUrl)
    quiet_logs(_spark)
# Out:
# INFO:__main__:spark web UI: http://10.14.6.24:4044

# %% [markdown]
# ## `naaccr-xml` Data Dictionary

# %%
if IO_TESTING:
    ddictDF(_spark).createOrReplaceTempView('ndd180')
IO_TESTING and _spark.table('ndd180').limit(5).toPandas().set_index('naaccrId')
# Out:
#                      naaccrNum             naaccrName parentXmlElement  \
# naaccrId
# recordType                  10            Record Type       NaaccrData
# registryType                30          Registry Type       NaaccrData
# naaccrRecordVersion         50  NAACCR Record Version       NaaccrData
# npiRegistryId               45       NPI--Registry ID       NaaccrData
# registryId                  40            Registry ID       NaaccrData
#
#                     dataType   padding  trim  startColumn  length  \
# naaccrId
# recordType              None      None  None            1       1
# registryType          digits      None  None            2       1
# naaccrRecordVersion   digits      None  None           17       3
# npiRegistryId         digits      None  None           20      10
# registryId            digits  leftZero  None           30      10
#
#                     allowUnlimitedText sourceOfStandard recordTypes
# naaccrId
# recordType                        None             None     A,M,C,I
# registryType                      None             None     A,M,C,I
# naaccrRecordVersion               None             None     A,M,C,I
# npiRegistryId                     None             None     A,M,C,I
# registryId                        None             None     A,M,C,I

# %%
if IO_TESTING:
    _spark.sql("""create or replace temporary view current_task as select 'abc' task_id from (values('X'))""")
    _ont = NAACCR_I2B2.ont_view_in(_spark)  # TODO: seer recode in NAACCR_ONTOLOGY
IO_TESTING and _ont.limit(5).toPandas()
# Out:
# /opt/spark-2.2.1-bin-hadoop2.7/python/lib/pyspark.zip/pyspark/sql/session.py:336: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"
# WARNING:tumor_reg_ont:skipping SEER Recode terms
# INFO:tumor_reg_ont:naaccr_concepts_load.sql: section = DataFrame[sectionid: bigint, section: string]
# INFO:tumor_reg_ont:naaccr_concepts_load.sql: tumor_item_type = DataFrame[naaccrNum: bigint, sectionId: bigint, section: string, naaccrId: string, naaccrName: string, length: bigint, source: string, loinc_num: string, scale_typ: string, AnswerListId: string, scheme: string, valtype_cd: string, phi_id_kind: string]
# INFO:tumor_reg_ont:naaccr_concepts_load.sql: code_labels = DataFrame[item: bigint, name: string, scheme: string, code: string, label: string, means_missing: boolean, description: string]
# INFO:tumor_reg_ont:naaccr_concepts_load.sql: seer_site_terms = DataFrame[hlevel: int, path: string, name: string, basecode: string, visualattributes: string]
# INFO:tumor_reg_ont:naaccr_concepts_load.sql: create naaccr_code_values
# INFO:tumor_reg_ont:naaccr_concepts_load.sql: create naaccr_ont_aux
# INFO:tumor_reg_ont:naaccr_concepts_load.sql: create naaccr_ont_aux_seer
# INFO:tumor_reg_ont:naaccr_concepts_load.sql: create naaccr_ontology
#    c_hlevel                                         c_fullname  \
# 0         1                                      \i2b2\naaccr\
# 1         2            \i2b2\naaccr\S:1 Cancer Identification\
# 2         2                      \i2b2\naaccr\S:2 Demographic\
# 3         2  \i2b2\naaccr\S:3 Edit Overrides/Conversion His...
# 4         2       \i2b2\naaccr\S:4 Follow-up/Recurrence/Death\
#
#                                               c_name c_basecode  \
# 0                    Cancer Cases (NAACCR Hierarchy)       None
# 1                           01 Cancer Identification       None
# 2                                     02 Demographic       None
# 3  03 Edit Overrides/Conversion History/System Admin       None
# 4                      04 Follow-up/Recurrence/Death       None
#
#                                            c_dimcode c_comment  \
# 0                                      \i2b2\naaccr\       abc
# 1            \i2b2\naaccr\S:1 Cancer Identification\       abc
# 2                      \i2b2\naaccr\S:2 Demographic\       abc
# 3  \i2b2\naaccr\S:3 Edit Overrides/Conversion His...       abc
# 4       \i2b2\naaccr\S:4 Follow-up/Recurrence/Death\       abc
#
#   c_visualattributes c_synonym_cd c_facttablecolumn        c_tablename  \
# 0                 FA            N        concept_cd  concept_dimension
# 1                 FA            N        concept_cd  concept_dimension
# 2                 FA            N        concept_cd  concept_dimension
# 3                 FA            N        concept_cd  concept_dimension
# 4                 FA            N        concept_cd  concept_dimension
#
#    c_columnname c_columndatatype c_operator m_applied_path  \
# 0  CONCEPT_PATH                T       like              @
# 1  CONCEPT_PATH                T       like              @
# 2  CONCEPT_PATH                T       like              @
# 3  CONCEPT_PATH                T       like              @
# 4  CONCEPT_PATH                T       like              @
#
#               update_date             import_date           sourcesystem_cd
# 0 2019-09-09 17:10:29.503 2019-09-09 17:10:29.503  tumor_registry@kumed.com
# 1 2019-09-09 17:10:29.503 2019-09-09 17:10:29.503  tumor_registry@kumed.com
# 2 2019-09-09 17:10:29.503 2019-09-09 17:10:29.503  tumor_registry@kumed.com
# 3 2019-09-09 17:10:29.503 2019-09-09 17:10:29.503  tumor_registry@kumed.com
# 4 2019-09-09 17:10:29.503 2019-09-09 17:10:29.503  tumor_registry@kumed.com

# %% [markdown]
# ## tumor_item_type: numeric /  date / nominal / text; identifier?

# %%
IO_TESTING and _spark.sql('''
select *
from ndd180 as idef
''').limit(8).toPandas()
# Out:
#               naaccrId  naaccrNum              naaccrName parentXmlElement  \
# 0           recordType         10             Record Type       NaaccrData
# 1         registryType         30           Registry Type       NaaccrData
# 2  naaccrRecordVersion         50   NAACCR Record Version       NaaccrData
# 3        npiRegistryId         45        NPI--Registry ID       NaaccrData
# 4           registryId         40             Registry ID       NaaccrData
# 5    tumorRecordNumber         60     Tumor Record Number            Tumor
# 6      patientIdNumber         20       Patient ID Number          Patient
# 7  patientSystemIdHosp         21  Patient System ID-Hosp            Tumor
#
#   dataType   padding  trim  startColumn  length allowUnlimitedText  \
# 0     None      None  None            1       1               None
# 1   digits      None  None            2       1               None
# 2   digits      None  None           17       3               None
# 3   digits      None  None           20      10               None
# 4   digits  leftZero  None           30      10               None
# 5   digits  leftZero  None           40       2               None
# 6   digits  leftZero  None           42       8               None
# 7   digits  leftZero  None           50       8               None
#
#   sourceOfStandard recordTypes
# 0             None     A,M,C,I
# 1             None     A,M,C,I
# 2             None     A,M,C,I
# 3             None     A,M,C,I
# 4             None     A,M,C,I
# 5             None     A,M,C,I
# 6             None     A,M,C,I
# 7             None     A,M,C,I

# %%
if IO_TESTING:
    NAACCR_R.field_info_in(_spark)
IO_TESTING and _spark.table('field_info').limit(5).toPandas()
# Out:
#    item                 name       type
# 0    10           recordType     factor
# 1    20      patientIdNumber  character
# 2    21  patientSystemIdHosp  character
# 3    30         registryType     factor
# 4    35      finCodingSystem  character

# %% [markdown]
# `WerthPADOH/naaccr` has complete coverage:

# %%
# TODO: turn this into a doctest, independent of Spark
IO_TESTING and _spark.sql('''
with check as (
select case when r.item is null then 0 else 1 end as has_r
from ndd180 v18
left join field_info r on r.item = v18.naaccrNum
)
select has_r, count(*) from check
group by has_r

order by has_r
''').toPandas()
# Out:
#    has_r  count(1)
# 0      1       772

# %% [markdown]
# Werth assigns a `type` to each item:

# %%
IO_TESTING and _spark.sql('''
select rl.section, type, nd.length, count(*), collect_list(rl.`naaccr-item-num`), collect_list(naaccrId)
from ndd180 nd
left join field_info f on f.item = nd.naaccrNum
left join record_layout rl on rl.`naaccr-item-num` = nd.naaccrNum
group by section, type, nd.length
order by section, type, nd.length
''').toPandas()
# Out:
#                                             section                type  \
# 0                                              None        census_block
# 1                                              None        census_tract
# 2                                              None           character
# 3                                              None           character
# 4                                              None           character
# 5                                              None           character
# 6                                              None              county
# 7                                              None  sentineled_integer
# 8                             Cancer Identification                Date
# 9                             Cancer Identification           character
# 10                            Cancer Identification           character
# 11                            Cancer Identification              factor
# 12                            Cancer Identification              factor
# 13                            Cancer Identification  sentineled_integer
# 14                                      Demographic                Date
# 15                                      Demographic                 age
# 16                                      Demographic           boolean01
# 17                                      Demographic           character
# 18                                      Demographic           character
# 19                                      Demographic                city
# 20                                      Demographic              county
# 21                                      Demographic              factor
# 22                                      Demographic              factor
# 23                                      Demographic              factor
# 24                                      Demographic              factor
# 25                                      Demographic              postal
# 26   Edit Overrides/Conversion History/System Admin                Date
# 27   Edit Overrides/Conversion History/System Admin           character
# 28   Edit Overrides/Conversion History/System Admin           character
# 29   Edit Overrides/Conversion History/System Admin           character
# ..                                              ...                 ...
# 97                         Stage/Prognostic Factors              factor
# 98                         Stage/Prognostic Factors              factor
# 99                         Stage/Prognostic Factors               icd_9
# 100                        Stage/Prognostic Factors  sentineled_integer
# 101                        Stage/Prognostic Factors  sentineled_integer
# 102                        Stage/Prognostic Factors  sentineled_numeric
# 103                        Stage/Prognostic Factors  sentineled_numeric
# 104                        Stage/Prognostic Factors  sentineled_numeric
# 105                        Stage/Prognostic Factors  sentineled_numeric
# 106                        Stage/Prognostic Factors  sentineled_numeric
# 107                                  Text-Diagnosis           character
# 108                                  Text-Diagnosis           character
# 109                              Text-Miscellaneous           character
# 110                              Text-Miscellaneous           character
# 111                                  Text-Treatment           character
# 112                            Treatment-1st Course                Date
# 113                            Treatment-1st Course           character
# 114                            Treatment-1st Course           character
# 115                            Treatment-1st Course           character
# 116                            Treatment-1st Course               count
# 117                            Treatment-1st Course              factor
# 118                            Treatment-1st Course              factor
# 119                            Treatment-1st Course             integer
# 120                            Treatment-1st Course  sentineled_integer
# 121                            Treatment-1st Course  sentineled_integer
# 122                            Treatment-1st Course  sentineled_integer
# 123                            Treatment-1st Course  sentineled_integer
# 124                    Treatment-Subsequent & Other                Date
# 125                    Treatment-Subsequent & Other           character
# 126                    Treatment-Subsequent & Other           character
#
#      length  count(1)                      collect_list(naaccr-item-num)  \
# 0         1         4                                                 []
# 1         6         4                                                 []
# 2         1        26                                                 []
# 3         2        12                                                 []
# 4         3         1                                                 []
# 5         4         3                                                 []
# 6         3         4                                                 []
# 7         2         2                                                 []
# 8         8         3                                    [443, 390, 445]
# 9         2         3                                    [439, 448, 391]
# 10        4         1                                              [400]
# 11        1        11  [442, 450, 449, 500, 490, 460, 441, 440, 480, ...
# 12        2         2                                         [501, 444]
# 13        2         2                                         [446, 380]
# 14        8         1                                              [240]
# 15        3         1                                              [230]
# 16        1         1                                              [192]
# 17        2         1                                              [241]
# 18      100         2                                         [320, 310]
# 19       50         1                                               [70]
# 20        3         2                                           [89, 90]
# 21        1        21  [191, 367, 330, 190, 145, 369, 365, 341, 150, ...
# 22        2        13  [3312, 1942, 161, 193, 3300, 252, 160, 80, 162...
# 23        3         8        [270, 250, 1944, 1832, 254, 280, 102, 1847]
# 24        4         2                                         [272, 282]
# 25        9         1                                              [100]
# 26        8         8   [2112, 2113, 2110, 2090, 2085, 2100, 2111, 2092]
# 27        2         1                                             [2200]
# 28        4         1                                             [1960]
# 29       10         2                                       [2170, 2081]
# ..      ...       ...                                                ...
# 97        2        10  [990, 3921, 3836, 3838, 1060, 1130, 930, 3816,...
# 98        5         3                                 [3605, 3610, 3614]
# 99        5        10  [3120, 3161, 3110, 3163, 3150, 3130, 3162, 316...
# 100       2        19  [3841, 3828, 3901, 3882, 834, 3897, 3891, 3895...
# 101       3         9  [752, 3914, 756, 754, 3870, 3925, 3903, 3826, ...
# 102       3         2                                       [3860, 3832]
# 103       4        10  [3888, 3823, 3824, 3853, 3887, 3892, 3817, 388...
# 104       5         5                     [3863, 3813, 3908, 3803, 3920]
# 105       6         2                                       [3820, 3810]
# 106       7         5                     [3848, 3846, 3807, 3932, 3805]
# 107     100         2                                       [2590, 2580]
# 108    1000         7         [2570, 2520, 2530, 2550, 2560, 2540, 2600]
# 109      60         1                                             [2690]
# 110    1000         1                                             [2680]
# 111    1000         7         [2660, 2650, 2630, 2610, 2670, 2640, 2620]
# 112       8        13  [1280, 1200, 1210, 1240, 1250, 1230, 3170, 318...
# 113       1         4                           [1330, 1647, 1310, 1648]
# 114       2        16  [1211, 1241, 1640, 1231, 1251, 1271, 1201, 126...
# 115       5         2                                       [3210, 1510]
# 116       3         1                                             [1520]
# 117       1        14  [1360, 1550, 1420, 1639, 1340, 1430, 3270, 129...
# 118       2        22  [1526, 3200, 1505, 1540, 1460, 1504, 1516, 153...
# 119       2         1                                             [1532]
# 120       2         1                                             [1296]
# 121       3         3                                 [1513, 1503, 1523]
# 122       5         3                                 [1501, 1521, 1511]
# 123       6         4                           [1527, 1517, 1533, 1507]
# 124       8         3                                 [1700, 1660, 1680]
# 125       1         1                                             [1741]
# 126       2         3                                 [1681, 1661, 1701]
#
#                                 collect_list(naaccrId)
# 0    [censusBlockGroup2010, censusBlockGrp197090, c...
# 1    [censusTract2000, censusTract19708090, censusT...
# 2    [subsqRx2ndScopeLnSu, subsqRx3rdScopeLnSu, beh...
# 3    [subsqRx2ndCourseSurg, subsqRx4thCourseSurg, s...
# 4                                       [eodTumorSize]
# 5    [histologyIcdO2, histologyIcdO1, histologicTyp...
# 6    [countyAtDxGeocode1990, countyAtDxGeocode2000,...
# 7       [regionalNodesExamined, regionalNodesPositive]
# 8    [dateConclusiveDx, dateOfDiagnosis, dateOfMult...
# 9    [dateOfMultTumorsFlag, dateConclusiveDxFlag, d...
# 10                                       [primarySite]
# 11   [ambiguousTerminologyDx, siteCodingSysCurrent,...
# 12            [casefindingSource, multTumRptAsOnePrim]
# 13        [multiplicityCounter, sequenceNumberCentral]
# 14                                       [dateOfBirth]
# 15                                    [ageAtDiagnosis]
# 16                                           [ihsLink]
# 17                                   [dateOfBirthFlag]
# 18            [textUsualIndustry, textUsualOccupation]
# 19                                      [addrAtDxCity]
# 20                    [countyAtDxAnalysis, countyAtDx]
# 21   [nhiaDerivedHispOrigin, censusTrCertainty2010,...
# 22   [ruralurbanContinuum2013, placeOfDeathState, r...
# 23   [censusOccCode19702000, birthplace, placeOfDea...
# 24              [censusIndCode2010, censusOccCode2010]
# 25                                [addrAtDxPostalCode]
# 26   [dateCaseReportLoaded, dateTumorRecordAvailbl,...
# 27                                [diagnosticProc7387]
# 28                                         [siteIcdO1]
# 29                           [vendorName, crcChecksum]
# ..                                                 ...
# 97   [tnmClinStagedBy, residualTumVolPostCytoreduct...
# 98   [derivedSeerPathStgGrp, derivedSeerClinStgGrp,...
# 99   [comorbidComplication2, comorbidComplication7,...
# 100  [gleasonScorePathological, estrogenReceptorTot...
# 101  [tumorSizeClinical, progesteroneRecepPrcntPosO...
# 102  [iNRProthrombinTime, extranodalExtensionHeadNe...
# 103  [measuredThickness, circumferentialResectionMa...
# 104  [ki67, bilirubinPretxTotalLabValue, percentNec...
# 105  [ceaPretreatmentLabValue, afpPretreatmentLabVa...
# 106  [hcgPreOrchiectomyLabValue, hcgPostOrchiectomy...
# 107         [textHistologyTitle, textPrimarySiteTitle]
# 108  [textDxProcPath, textDxProcPe, textDxProcXRayS...
# 109                             [textPlaceOfDiagnosis]
# 110                                      [textRemarks]
# 111  [rxTextBrm, rxTextHormone, rxTextRadiationOthe...
# 112  [rxDateDxStgProc, rxDateSurgery, rxDateRadiati...
# 113  [rxSummReconstruct1st, rxSummScopeReg9802, rxS...
# 114  [rxDateRadiationFlag, rxDateBrmFlag, rxSummSur...
# 115              [radBoostDoseCgy, radRegionalDoseCgy]
# 116                              [radNoOfTreatmentVol]
# 117  [rxSummRadiation, radLocationOfRx, rxSummOther...
# 118  [phase3RadiationTreatmentModality, radBoostRxM...
# 119                      [numberPhasesOfRadTxToVolume]
# 120                              [rxSummRegLnExamined]
# 121  [phase2NumberOfFractions, phase1NumberOfFracti...
# 122  [phase1DosePerFraction, phase3DosePerFraction,...
# 123  [phase3TotalDose, phase2TotalDose, totalDose, ...
# 124  [subsqRx4thCourseDate, subsqRx2ndCourseDate, s...
# 125                            [subsqRxReconstructDel]
# 126  [subsqRx3rdcrsDateFlag, subsqRx2ndcrsDateFlag,...
#
# [127 rows x 6 columns]

# %% [markdown]
# ### Mixednaaccr-xml, LOINC, and Werth

# %%
if IO_TESTING:
    _spark.createDataFrame(NAACCR_I2B2.tumor_item_type).createOrReplaceTempView('tumor_item_type')

# %% [markdown]
# #### Any missing?

# %%
IO_TESTING and _spark.sql('''
select *
from tumor_item_type
where valtype_cd is null or  scale_typ is null
''').toPandas().sort_values(['sectionId', 'naaccrNum']).reset_index(drop=True)
# Out:
# Empty DataFrame
# Columns: [naaccrNum, sectionId, section, naaccrId, naaccrName, length, source, loinc_num, scale_typ, AnswerListId, scheme, valtype_cd, phi_id_kind]
# Index: []

# %% [markdown]
# #### Ambiguous valtype_cd?

# %%
IO_TESTING and _spark.sql('''
select naaccrId, length, count(distinct valtype_cd), collect_list(valtype_cd)
from tumor_item_type
group by naaccrId, length
having count(distinct valtype_cd) > 1
''').toPandas()
# Out:
# Empty DataFrame
# Columns: [naaccrId, length, count(DISTINCT valtype_cd), collect_list(valtype_cd)]
# Index: []

# %% [markdown]
# **ISSUE: LOINC mapping is ambiguous!**

# %%
IO_TESTING and _spark.sql('''
select naaccrId, count(distinct valtype_cd), collect_list(valtype_cd), collect_list(loinc_num)
from tumor_item_type
group by naaccrId
having count(*) > 1
''').toPandas()
# Out:
# Empty DataFrame
# Columns: [naaccrId, count(DISTINCT valtype_cd), collect_list(valtype_cd), collect_list(loinc_num)]
# Index: []

# %%
def csv_meta(dtypes: Dict[str, np.dtype], path: str,
             context: str = 'http://www.w3.org/ns/csvw') -> Dict[str, object]:
    # ISSUE: dead code? obsolete in favor of _fixna()?
    def xlate(dty: np.dtype) -> str:
        if dty.kind == 'i':
            return 'number'
        elif dty.kind == 'O':
            return 'string'
        raise NotImplementedError(dty.kind)

    cols = [
        {"titles": name,
         "datatype": xlate(dty)}
        for name, dty in dtypes.items()
    ]
    return {"@context": context,
            "url": path,
            "tableSchema": {
                "columns": cols
            }}

# %%
def csv_spark_schema(columns: List[Dict[str, str]]) -> ty.StructType:
    """
    Note: limited to exactly 1 titles per column
    IDEA: expand to boolean
    IDEA: nullable / required
    """
    def oops(what: object) -> NoReturn:
        raise NotImplementedError(what)
    fields = [
        ty.StructField(
            name=col['titles'],
            dataType=ty.IntegerType() if col['datatype'] == 'number'
            else ty.StringType() if col['datatype'] == 'string'
            else oops(col))
        for col in columns]
    return ty.StructType(fields)

# IDEA: csv_spark_schema(csv_meta(x.dtypes, 'tumor_item_type.csv')['tableSchema']['columns'])

# %% [markdown]
# ## Coded Concepts

# %%
if IO_TESTING:
    LOINC_NAACCR.answers_in(_spark)

IO_TESTING and _spark.table('loinc_naaccr_answers').where('code_value = 380').limit(5).toPandas()
# Out:
#   loinc_number                        component code_system code_value  \
# 0      21853-7  Sequence number central.patient   NAACCR_ID        380
# 1      21853-7  Sequence number central.patient   NAACCR_ID        380
# 2      21853-7  Sequence number central.patient   NAACCR_ID        380
# 3      21853-7  Sequence number central.patient   NAACCR_ID        380
# 4      21853-7  Sequence number central.patient   NAACCR_ID        380
#
#   answerlistid                 answerlistname answer_code  sequence_no  \
# 0      LL210-6  CR_380_Cancer sequence number          00            1
# 1      LL210-6  CR_380_Cancer sequence number          01            2
# 2      LL210-6  CR_380_Cancer sequence number          02            3
# 3      LL210-6  CR_380_Cancer sequence number          98            4
# 4      LL210-6  CR_380_Cancer sequence number          99            5
#
#                                        answer_string
# 0                                   One primary only
# 1                     First of one or more primaries
# 2                    Second of two or more primaries
# 3  Case of carcinoma in situ of the cervix diagno...
# 4                        Unspecified sequence number

# %% [markdown]
# #### Werth Code Values

# %%
if IO_TESTING:
    _spark.createDataFrame(NAACCR_R.field_code_scheme).createOrReplaceTempView('field_code_scheme')
    _spark.createDataFrame(NAACCR_R.code_labels()).createOrReplaceTempView('code_labels')
IO_TESTING and _spark.table('code_labels').limit(5).toPandas().set_index(['item', 'name', 'scheme', 'code'])
# Out:
#                                         label  means_missing  \
# item name       scheme     code
# 10   recordType recordType I        incidence          False
#                            C     confidential          False
#                            A         abstract          False
#                            U           update          False
#                            M         modified          False
#
#                                                                        description
# item name       scheme     code
# 10   recordType recordType I     Incidence-only record type (nonconfidential co...
#                            C     Confidential record type (incidence record plu...
#                            A     Full case Abstract record type (incidence and ...
#                            U     Correction/ Update record type (short format r...
#                            M     Record Modified since previous submission to c...

# %% [markdown]
# ## NAACCR XML Data

# %%
class NAACCR2:
    s100x = XML.parse(GzipFile(fileobj=res.open_binary(  # type: ignore # typeshed/issues/2580  # noqa
        naaccr_xml_samples, 'naaccr-xml-sample-v180-incidence-100.xml.gz')))

    @classmethod
    def s100t(cls) -> ContextManager[Path_T]:
        """
        TODO: check in results of converting from XML sample
        using `java -jar ~/opt/naaccr-xml-utility-6.2/lib/naaccr-xml-utility.jar`  # noqa
        """
        return res.path(
            naaccr_xml_samples, 'naaccr-xml-sample-v180-incidence-100.txt')

# %%
def tumorDF(spark: SparkSession_T, doc: XML.ElementTree) -> DataFrame:
    rownum = 0
    ns = {'n': 'http://naaccr.org/naaccrxml'}

    to_parent = {c: p for p in doc.iter() for c in p}

    def tumorItems(tumorElt: XML.Element, schema: ty.StructType,
                   simpleContent: bool = True) -> Iterator[Dict[str, object]]:
        nonlocal rownum
        assert simpleContent
        rownum += 1
        patElt = to_parent[tumorElt]
        ndataElt = to_parent[patElt]
        for elt in [ndataElt, patElt, tumorElt]:
            for item in elt.iterfind('./n:Item', ns):
                for itemRecord in eltDict(item, schema, simpleContent):
                    yield dict(itemRecord, rownum=rownum)

    itemSchema = eltSchema(NAACCR1.item_xsd, simpleContent=True)
    rownumField = ty.StructField('rownum', ty.IntegerType(), False)
    tumorItemSchema = ty.StructType([rownumField] + itemSchema.fields)
    data = xmlDF(spark, schema=tumorItemSchema, doc=doc, path='.//n:Tumor',
                 eltRecords=tumorItems,
                 ns={'n': 'http://naaccr.org/naaccrxml'},
                 simpleContent=True)
    return data.drop('naaccrNum')


IO_TESTING and (tumorDF(_spark, NAACCR2.s100x)
                .toPandas().sort_values(['naaccrId', 'rownum']).head(5))
# Out:
#      rownum        naaccrId value
# 54        1  ageAtDiagnosis   066
# 114       2  ageAtDiagnosis   080
# 189       3  ageAtDiagnosis   030
# 297       4  ageAtDiagnosis   042
# 357       5  ageAtDiagnosis   071

# %% [markdown]
# What columns are covered by the 100 tumor sample?

# %%
IO_TESTING and (tumorDF(_spark, NAACCR2.s100x)  # type: ignore
                .select('naaccrId').distinct().sort('naaccrId')
                .toPandas().naaccrId.values)
# Out:
# array(['ageAtDiagnosis', 'behaviorCodeIcdO3', 'birthplaceCountry',
#        'birthplaceState', 'causeOfDeath', 'censusTrCertainty2000',
#        'censusTrCertainty2010', 'censusTrPovertyIndictr',
#        'censusTract2000', 'censusTract2010', 'computedEthnicity',
#        'computedEthnicitySource', 'csExtension', 'csLymphNodes',
#        'csLymphNodesEval', 'csMetsAtDx', 'csMetsAtDxBone',
#        'csMetsAtDxBrain', 'csMetsAtDxLiver', 'csMetsAtDxLung',
#        'csMetsEval', 'csSiteSpecificFactor1', 'csSiteSpecificFactor10',
#        'csSiteSpecificFactor11', 'csSiteSpecificFactor12',
#        'csSiteSpecificFactor13', 'csSiteSpecificFactor14',
#        'csSiteSpecificFactor15', 'csSiteSpecificFactor16',
#        'csSiteSpecificFactor17', 'csSiteSpecificFactor18',
#        'csSiteSpecificFactor19', 'csSiteSpecificFactor2',
#        'csSiteSpecificFactor20', 'csSiteSpecificFactor21',
#        'csSiteSpecificFactor22', 'csSiteSpecificFactor23',
#        'csSiteSpecificFactor24', 'csSiteSpecificFactor25',
#        'csSiteSpecificFactor3', 'csSiteSpecificFactor4',
#        'csSiteSpecificFactor5', 'csSiteSpecificFactor6',
#        'csSiteSpecificFactor7', 'csSiteSpecificFactor8',
#        'csSiteSpecificFactor9', 'csTumorSize', 'csTumorSizeExtEval',
#        'csVersionDerived', 'csVersionInputCurrent',
#        'csVersionInputOriginal', 'dateConclusiveDx', 'dateInitialRxSeer',
#        'dateOfBirth', 'dateOfDiagnosis', 'dateOfLastContact',
#        'dateOfMultTumors', 'derivedAjcc6M', 'derivedAjcc6MDescript',
#        'derivedAjcc6N', 'derivedAjcc6NDescript', 'derivedAjcc6StageGrp',
#        'derivedAjcc6T', 'derivedAjcc6TDescript', 'derivedAjcc7M',
#        'derivedAjcc7MDescript', 'derivedAjcc7N', 'derivedAjcc7NDescript',
#        'derivedAjcc7StageGrp', 'derivedAjcc7T', 'derivedAjcc7TDescript',
#        'derivedAjccFlag', 'derivedSs1977', 'derivedSs1977Flag',
#        'derivedSs2000', 'derivedSs2000Flag', 'diagnosticConfirmation',
#        'grade', 'histologicTypeIcdO3', 'icdRevisionNumber', 'laterality',
#        'lymphVascularInvasion', 'maritalStatusAtDx',
#        'multTumRptAsOnePrim', 'multiplicityCounter',
#        'nhiaDerivedHispOrigin', 'patientIdNumber', 'primaryPayerAtDx',
#        'primarySite', 'race1', 'race2', 'race3', 'race4', 'race5',
#        'raceNapiia', 'reasonForNoSurgery', 'regionalNodesExamined',
#        'regionalNodesPositive', 'rxSummBrm', 'rxSummChemo',
#        'rxSummDxStgProc', 'rxSummHormone', 'rxSummOther',
#        'rxSummPalliativeProc', 'rxSummRadToCns', 'rxSummRadiation',
#        'rxSummRegLnExamined', 'rxSummScopeReg9802', 'rxSummScopeRegLnSur',
#        'rxSummSurgOth9802', 'rxSummSurgOthRegDis', 'rxSummSurgPrimSite',
#        'rxSummSurgRadSeq', 'rxSummSurgSite9802', 'rxSummSurgicalMargins',
#        'rxSummSystemicSurSeq', 'rxSummTransplntEndocr',
#        'rxSummTreatmentStatus', 'seerCodingSysCurrent',
#        'seerRecordNumber', 'seerTypeOfFollowUp', 'sequenceNumberCentral',
#        'sex', 'spanishHispanicOrigin', 'tumorMarker1', 'tumorMarker2',
#        'tumorMarker3', 'tumorRecordNumber', 'typeOfReportingSource',
#        'vitalStatus'], dtype=object)

# %%
def naaccr_pivot(ddict: DataFrame, skinny: DataFrame, key_cols: List[str],
                 pivot_on: str = 'naaccrId', value_col: str = 'value',
                 start: str = 'startColumn') -> DataFrame:
    groups = skinny.select(pivot_on, value_col, *key_cols).groupBy(*key_cols)
    wide = groups.pivot(pivot_on).agg(func.first(value_col))
    start_by_id = {id: start
                   for (id, start) in ddict.select(pivot_on, start).collect()}
    sorted_cols = sorted(wide.columns, key=lambda id: start_by_id.get(id, -1))
    return wide.select(cast(List[Union[sq.Column, str]], sorted_cols))


IO_TESTING and (naaccr_pivot(ddictDF(_spark),
                             tumorDF(_spark, NAACCR2.s100x),
                             ['rownum'])
                .limit(3).toPandas())
# Out:
#    rownum tumorRecordNumber patientIdNumber censusTract2000  \
# 0      31                01        00000038          999999
# 1      85                01        00000089          999999
# 2      65                01        00000069          999999
#
#   censusTrCertainty2000 censusTract2010 censusTrCertainty2010  \
# 0                     9          999999                     9
# 1                     9          999999                     9
# 2                     9          999999                     9
#
#   maritalStatusAtDx race1 race2  ... rxSummSurgSite9802 rxSummScopeReg9802  \
# 0                 1    01    88  ...               None               None
# 1                 3    01    88  ...               None               None
# 2                 4    01    88  ...               None               None
#
#   rxSummSurgOth9802 seerCodingSysCurrent seerTypeOfFollowUp seerRecordNumber  \
# 0              None                    9                  2               01
# 1              None                    F                  2               01
# 2              None                    F                  2               01
#
#   dateOfLastContact vitalStatus causeOfDeath icdRevisionNumber
# 0          20170308           1         0000                 0
# 1          20190311           1         0000                 0
# 2          20190218           1         0000                 0
#
# [3 rows x 131 columns]

# %% [markdown]
# ## NAACCR Flat File v18

# %%
if IO_TESTING:
    with NAACCR2.s100t() as _tr_file:
        log.info('tr_file: %s', _tr_file)
        _naaccr_text_lines = _spark.read.text(str(_tr_file))
else:
    _naaccr_text_lines = cast(DataFrame, None)
# Out:
# INFO:__main__:tr_file: /home/dconnolly/projects/naaccr-tumor-data/naaccr_xml_samples/naaccr-xml-sample-v180-incidence-100.txt

# %%
IO_TESTING and _naaccr_text_lines.rdd.getNumPartitions()
# Out:
# 1

# %%
IO_TESTING and _naaccr_text_lines.limit(5).toPandas()
# Out:
#                                                value
# 0  I               180                    0100000...
# 1  I               180                    0100000...
# 2  I               180                    0100000...
# 3  I               180                    0100000...
# 4  I               180                    0100000...

# %%
def non_blank(df: pd.DataFrame) -> pd.DataFrame:
    return df[[
        col for col in df.columns
        if (df[col].str.strip() > '').any()
    ]]

# %%
def naaccr_read_fwf(flat_file: DataFrame, itemDefs: DataFrame,
                    value_col: str = 'value',
                    exclude_pfx: str = 'reserved') -> DataFrame:
    """
    @param flat_file: as from spark.read.text()
                      typically with .value
    @param itemDefs: see ddictDF. ISSUE: should just use static CSV data now.
    """
    fields = [
        func.substring(flat_file[value_col],
                       item.startColumn, item.length).alias(item.naaccrId)
        for item in itemDefs.collect()
        if not item.naaccrId.startswith(exclude_pfx)
    ]  # type: List[Union[sq.Column, str]]
    return flat_file.select(fields)


_extract = cast(DataFrame, None)  # for static analysis when not IO_TESTING
if IO_TESTING:
    _extract = naaccr_read_fwf(_naaccr_text_lines, ddictDF(_spark))
    _extract.createOrReplaceTempView('naaccr_extract')
# _extract.explain()
IO_TESTING and non_blank(_extract.limit(5).toPandas())
# Out:
#   recordType naaccrRecordVersion tumorRecordNumber patientIdNumber  \
# 0          I                 180                01        00000010
# 1          I                 180                01        00000011
# 2          I                 180                01        00000012
# 3          I                 180                01        00000013
# 4          I                 180                01        00000014
#
#   censusTract2000 censusTrCertainty2000 censusTract2010 censusTrCertainty2010  \
# 0          999999                     9          999999                     9
# 1          999999                     9          999999                     9
# 2          999999                     9          999999                     9
# 3          999999                     9          999999                     9
# 4          999999                     9          999999                     9
#
#   maritalStatusAtDx race1  ... rxSummBrm rxSummOther rxSummSystemicSurSeq  \
# 0                 5    02  ...        99           9                    9
# 1                 6    01  ...        99           9                    9
# 2                 2    01  ...        99           9                    9
# 3                 2    01  ...        99           9                    9
# 4                 2    01  ...        99           9                    9
#
#   seerCodingSysCurrent seerTypeOfFollowUp seerRecordNumber dateOfLastContact  \
# 0                    F                  2               01          20171019
# 1                    F                  2               01          20180710
# 2                    D                  2               01          20131216
# 3                    F                  2               01          20180916
# 4                    F                  2               01          20170328
#
#   vitalStatus causeOfDeath icdRevisionNumber
# 0           1         0000                 0
# 1           1         0000                 0
# 2           1         0000                 0
# 3           1         0000                 0
# 4           1         0000                 0
#
# [5 rows x 125 columns]

# %%
def cancerIdSample(spark: SparkSession_T, cache: Path_T, tumors: DataFrame,
                   portion: float = 1.0, cancerID: int = 1) -> DataFrame:
    """Cancer Identification items from a sample

    """
    cols = NAACCR_I2B2.tumor_item_type
    cols = cols[cols.sectionId == cancerID]
    colnames = cols.naaccrId.values.tolist()
    # TODO: test data for morphTypebehavIcdO2 etc.
    colnames = [cn for cn in colnames if cn in tumors.columns]
    return tumors.sample(False, portion).select(colnames)


if False and IO_TESTING:
    _cancer_id = cancerIdSample(_spark, _cwd / 'naaccr_ddict', _extract)

False and IO_TESTING and non_blank(_cancer_id.limit(15).toPandas())
# Out:
# False

# %%
False and IO_TESTING and _cancer_id.toPandas().describe()
# Out:
# False

# %% [markdown]
# ## NAACCR Dates
#
#  - **ISSUE**: hide date flags in i2b2? They just say why a date is missing, which doesn't seem worth the screenspace.

# %%
def naaccr_dates(df: DataFrame, date_cols: List[str],
                 keep: bool = False) -> DataFrame:
    orig_cols = df.columns
    for dtcol in date_cols:
        strcol = dtcol + '_'
        df = df.withColumnRenamed(dtcol, strcol)
        dt = func.substring(func.concat(func.trim(df[strcol]), func.lit('0101')), 1, 8)
        # df = df.withColumn(dtcol + '_str', dt)
        dt = func.to_date(dt, 'yyyyMMdd')
        df = df.withColumn(dtcol, dt)
    if not keep:
        df = df.select(cast(Union[sq.Column, str], orig_cols))
    return df


IO_TESTING and naaccr_dates(
    _extract.select(['dateOfDiagnosis', 'dateOfLastContact']),
    ['dateOfDiagnosis', 'dateOfLastContact'],
    keep=True).limit(10).toPandas()
# Out:
#   dateOfDiagnosis_ dateOfLastContact_ dateOfDiagnosis dateOfLastContact
# 0         20171019           20171019      2017-10-19        2017-10-19
# 1         20180710           20180710      2018-07-10        2018-07-10
# 2         20131216           20131216      2013-12-16        2013-12-16
# 3         20180916           20180916      2018-09-16        2018-09-16
# 4         20170328           20170328      2017-03-28        2017-03-28
# 5         20170902           20170902      2017-09-02        2017-09-02
# 6         20100425           20100425      2010-04-25        2010-04-25
# 7         20161105           20161105      2016-11-05        2016-11-05
# 8         20180420           20180420      2018-04-20        2018-04-20
# 9         20170210           20170210      2017-02-10        2017-02-10

# %% [markdown]
# ### Strange dates: TODO?

# %%
def strange_dates(extract: DataFrame) -> DataFrame:
    x = naaccr_dates(extract.select(['dateOfDiagnosis']),
                     ['dateOfDiagnosis'], keep=True)
    x = x.withColumn('dtlen', func.length(func.trim(x.dateOfDiagnosis_)))
    x = x.where(x.dtlen > 0)
    x = x.withColumn('cc', func.substring(func.trim(x.dateOfDiagnosis_), 1, 2))

    return x.where(
        ~(x.cc.isin(['19', '20'])) |
        ((x.dtlen < 8) & (x.dtlen > 0)))


IO_TESTING and (strange_dates(_extract)
                .toPandas().groupby(['dtlen', 'cc']).count())
# Out:
# Empty DataFrame
# Columns: [dateOfDiagnosis_, dateOfDiagnosis]
# Index: []

# %% [markdown]
# ## Patients, Tumors, Unique key columns
#
#  - `patientSystemIdHosp` - "This provides a stable identifier to
#    link back to all reported tumors for a patient. It also serves as
#    a reliable linking identifier; useful when central registries
#    send follow-up information back to hospitals. Other identifiers
#    such as social security number and medical record number, while
#    useful, are subject to change and are thus less useful for this
#    type of record linkage."
#
#  - `tumorRecordNumber` - "Description: A system-generated number
#     assigned to each tumor. The number should never change even if
#     the tumor sequence is changed or a record (tumor) is deleted.
#     Rationale: This is a unique number that identifies a specific
#     tumor so data can be linked. "Sequence Number" cannot be used as
#     a link because the number is changed if a report identifies an
#     earlier tumor or if a tumor record is deleted."
#
# Turns out to be not enough:

# %%
def dups(df_spark: DataFrame, key_cols: List[str]) -> pd.DataFrame:
    df_pd = df_spark.toPandas().sort_values(key_cols)
    df_pd['dup'] = df_pd.duplicated(key_cols, keep=False)
    return df_pd[df_pd.dup]


_key1 = ['patientSystemIdHosp', 'tumorRecordNumber']

IO_TESTING and dups(_extract.select('sequenceNumberCentral',
                                    'dateOfDiagnosis', 'dateCaseCompleted',
                                    *_key1),
                    _key1).set_index(_key1)
# Out:
#                                       sequenceNumberCentral dateOfDiagnosis  \
# patientSystemIdHosp tumorRecordNumber
#                     01                                   00        20171019
#                     01                                   00        20180710
#                     01                                   00        20131216
#                     01                                   00        20180916
#                     01                                   00        20170328
#                     01                                   00        20170902
#                     01                                   00        20100425
#                     01                                   00        20161105
#                     01                                   00        20180420
#                     01                                   00        20170210
#                     01                                   01        20181228
#                     01                                   00        20160217
#                     01                                   00        20190330
#                     01                                   00        20171229
#                     01                                   00        20170529
#                     01                                   00        20131218
#                     01                                   01        20161015
#                     01                                   00        20160708
#                     01                                   00        20180216
#                     01                                   00        20141003
#                     01                                   00        20181114
#                     01                                   00        20170109
#                     01                                   00        20170329
#                     01                                   00        20180331
#                     01                                   00        20190111
#                     01                                   00        20150524
#                     01                                   00        20151221
#                     01                                   00        20181123
#                     01                                   01        20080627
#                     01                                   00        20190412
# ...                                                     ...             ...
#                     01                                   00        20181111
#                     01                                   00        20181211
#                     01                                   00        20181220
#                     01                                   00        20170114
#                     01                                   00        20170409
#                     01                                   00        20180726
#                     01                                   00        20190125
#                     01                                   00        20190306
#                     01                                   00        20190201
#                     01                                   00        20190311
#                     01                                   00        20180727
#                     01                                   01        20181222
#                     01                                   00        20170805
#                     01                                   00        20170316
#                     01                                   00        20190119
#                     01                                   00        20141211
#                     01                                   00        20180205
#                     01                                   00        20170722
#                     01                                   00        20170202
#                     01                                   00        20171004
#                     01                                   00        20180911
#                     01                                   00        20171123
#                     01                                   00        20150201
#                     01                                   00        20161113
#                     02                                   02        20121208
#                     02                                   02        20000713
#                     02                                   02        20170308
#                     02                                   02        20161124
#                     02                                   02        20130503
#                     02                                   02        20180214
#
#                                       dateCaseCompleted   dup
# patientSystemIdHosp tumorRecordNumber
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
# ...                                                 ...   ...
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     01                                   True
#                     02                                   True
#                     02                                   True
#                     02                                   True
#                     02                                   True
#                     02                                   True
#                     02                                   True
#
# [100 rows x 4 columns]

# %%
class TumorKeys:
    # issue: accessionNumberHosp is not unique
    pat_ids = ['patientSystemIdHosp', 'patientIdNumber']
    pat_attrs = pat_ids + ['dateOfBirth', 'dateOfLastContact',
                           'sex', 'vitalStatus']
    tmr_ids = ['tumorRecordNumber']
    tmr_attrs = tmr_ids + [
        'dateOfDiagnosis',
        'sequenceNumberCentral', 'sequenceNumberHospital', 'primarySite',
        'ageAtDiagnosis', 'dateOfInptAdm', 'dateOfInptDisch', 'classOfCase',
        'dateCaseInitiated', 'dateCaseCompleted', 'dateCaseLastChanged',
    ]
    report_ids = ['naaccrRecordVersion', 'npiRegistryId']
    report_attrs = report_ids + ['dateCaseReportExported']

    dtcols = ['dateOfBirth', 'dateOfDiagnosis', 'dateOfLastContact',
              'dateCaseCompleted', 'dateCaseLastChanged']
    key4 = [
        'patientSystemIdHosp',  # NAACCR stable patient ID
        'tumorRecordNumber',    # NAACCR stable tumor ID
        'patientIdNumber',      # patient_mapping
        'abstractedBy',         # IDEA/YAGNI?: provider_id
    ]
    @classmethod
    def pat_tmr(cls, spark: SparkSession_T,
                naaccr_text_lines: DataFrame) -> DataFrame:
        return cls._pick_cols(spark, naaccr_text_lines,
                              cls.tmr_attrs + cls.pat_attrs + cls.report_attrs)

    @classmethod
    def patients(cls, spark: SparkSession_T,
                 naaccr_text_lines: DataFrame) -> DataFrame:
        pat = cls._pick_cols(spark, naaccr_text_lines,
                             cls.pat_ids + cls.pat_attrs +
                             cls.report_ids + cls.report_attrs)
        # distinct() wasn't fixed until the 3.x pre-release
        # https://github.com/zero323/pyspark-stubs/pull/138 623b0c0330ef
        return pat.distinct()  # type: ignore

    @classmethod
    def _pick_cols(cls, spark: SparkSession_T,
                   naaccr_text_lines: DataFrame,
                   cols: List[str]) -> DataFrame:
        dd = ddictDF(spark)
        pat_tmr = naaccr_read_fwf(
            naaccr_text_lines,
            dd.where(dd.naaccrId.isin(cols)))
        pat_tmr = naaccr_dates(pat_tmr,
                               [c for c in pat_tmr.columns
                                if c.startswith('date')])
        return pat_tmr

    @classmethod
    def with_tumor_id(cls, data: DataFrame,
                      name: str = 'recordId',
                      extra: List[str] = ['dateOfDiagnosis',
                                          'dateCaseCompleted'],
                      # keep recordId length consistent
                      extra_default: Opt[sq.Column] = None) -> DataFrame:
        # ISSUE: performance: add encounter_num column here?
        if extra_default is None:
            extra_default = func.lit('0000-00-00')
        id_col = func.concat(data.patientSystemIdHosp,
                             data.tumorRecordNumber,
                             *[func.coalesce(data[col], extra_default)
                               for col in extra])
        return data.withColumn(name, id_col)

    @classmethod
    def with_rownum(cls, tumors: DataFrame,
                    start: int = 1,
                    new_col: str = 'encounter_num',
                    key_col: str = 'recordId') -> DataFrame:
        tumors = tumors.withColumn(
            new_col,
            func.lit(start) +
            func.row_number().over(Window.orderBy(key_col)))
        return tumors

    @classmethod
    def export_patient_ids(cls, df: DataFrame, spark: SparkSession_T,
                           cdw: 'Account', schema: str,
                           tmp_table: str = 'NAACCR_PMAP',
                           id_col: str = 'patientIdNumber') -> None:
        log.info('writing %s to %s', id_col, tmp_table)
        cdw.wr(df.select(id_col).distinct().write,  # type: ignore
               tmp_table, mode='overwrite')

    @classmethod
    def with_patient_num(cls, df: DataFrame, spark: SparkSession_T,
                         cdw: 'Account', schema: str,
                         source: str,  # assumed injection-safe
                         tmp_table: str = 'NAACCR_PMAP',
                         id_col: str = 'patientIdNumber') -> DataFrame:
        cls.export_patient_ids(df, spark, cdw, schema,
                               id_col=id_col, tmp_table=tmp_table)
        q = f'''(
            select ea."{id_col}", pmap.PATIENT_NUM
            from {tmp_table} ea
            join {schema}.PATIENT_MAPPING pmap
            on pmap.patient_ide_source = '{source}'
            and ltrim(pmap.patient_ide, '0') = ltrim(ea."{id_col}", '0')
        )'''
        src_map = cdw.rd(spark.read, q)
        out = df.join(src_map, df[id_col] == src_map[id_col], how='left')
        out = out.drop(src_map[id_col])
        out = out.withColumnRenamed('PATIENT_NUM', 'patient_num')
        return out


# pat_tmr.cache()
if IO_TESTING:
    _pat_tmr = TumorKeys.with_rownum(TumorKeys.with_tumor_id(
        TumorKeys.pat_tmr(_spark, _naaccr_text_lines)))
    _patients = TumorKeys.patients(_spark, _naaccr_text_lines)
IO_TESTING and (_pat_tmr, _patients)
# Out:
# (DataFrame[naaccrRecordVersion: string, npiRegistryId: string, tumorRecordNumber: string, patientIdNumber: string, patientSystemIdHosp: string, sex: string, ageAtDiagnosis: string, dateOfBirth: date, sequenceNumberCentral: string, dateOfDiagnosis: date, primarySite: string, sequenceNumberHospital: string, dateOfInptAdm: date, dateOfInptDisch: date, classOfCase: string, dateCaseInitiated: date, dateCaseCompleted: date, dateCaseLastChanged: date, dateCaseReportExported: date, dateOfLastContact: date, vitalStatus: string, recordId: string, encounter_num: int],
#  DataFrame[naaccrRecordVersion: string, npiRegistryId: string, patientIdNumber: string, patientSystemIdHosp: string, sex: string, dateOfBirth: date, dateCaseReportExported: date, dateOfLastContact: date, vitalStatus: string])

# %%
IO_TESTING and _pat_tmr.limit(15).toPandas()
# Out:
#    naaccrRecordVersion npiRegistryId tumorRecordNumber patientIdNumber  \
# 0                  180                              01        00000065
# 1                  180                              01        00000038
# 2                  180                              01        00000016
# 3                  180                              01        00000012
# 4                  180                              01        00000025
# 5                  180                              01        00000068
# 6                  180                              01        00000059
# 7                  180                              01        00000029
# 8                  180                              01        00000062
# 9                  180                              01        00000095
# 10                 180                              01        00000040
# 11                 180                              01        00000102
# 12                 180                              01        00000035
# 13                 180                              01        00000075
# 14                 180                              01        00000057
#
#    patientSystemIdHosp sex ageAtDiagnosis dateOfBirth sequenceNumberCentral  \
# 0                        1            050  1931-09-13                    01
# 1                        2            053  1954-07-18                    01
# 2                        2            060  1949-09-13                    00
# 3                        1            030  1983-05-05                    00
# 4                        1            070  1943-02-11                    00
# 5                        1            063  1950-08-30                    00
# 6                        1            043  1971-04-28                    00
# 7                        2            081  1933-07-05                    00
# 8                        1            073  1941-07-21                    00
# 9                        1            062  1952-10-10                    00
# 10                       2            054  1960-12-03                    00
# 11                       1            044  1970-05-31                    00
# 12                       2            052  1962-06-26                    00
# 13                       1            073  1941-10-11                    00
# 14                       2            044  1971-01-09                    00
#
#    dateOfDiagnosis  ... dateOfInptDisch classOfCase dateCaseInitiated  \
# 0       1981-12-04  ...            None                          None
# 1       2008-06-27  ...            None                          None
# 2       2010-04-25  ...            None                          None
# 3       2013-12-16  ...            None                          None
# 4       2013-12-18  ...            None                          None
# 5       2014-05-29  ...            None                          None
# 6       2014-09-24  ...            None                          None
# 7       2014-10-03  ...            None                          None
# 8       2014-10-06  ...            None                          None
# 9       2014-12-11  ...            None                          None
# 10      2015-01-09  ...            None                          None
# 11      2015-02-01  ...            None                          None
# 12      2015-05-24  ...            None                          None
# 13      2015-08-24  ...            None                          None
# 14      2015-09-20  ...            None                          None
#
#    dateCaseCompleted dateCaseLastChanged dateCaseReportExported  \
# 0               None                None                   None
# 1               None                None                   None
# 2               None                None                   None
# 3               None                None                   None
# 4               None                None                   None
# 5               None                None                   None
# 6               None                None                   None
# 7               None                None                   None
# 8               None                None                   None
# 9               None                None                   None
# 10              None                None                   None
# 11              None                None                   None
# 12              None                None                   None
# 13              None                None                   None
# 14              None                None                   None
#
#    dateOfLastContact vitalStatus                        recordId encounter_num
# 0         2013-05-03           1          011981-12-040000-00-00             2
# 1         2017-03-08           1          012008-06-270000-00-00             3
# 2         2010-04-25           1          012010-04-250000-00-00             4
# 3         2013-12-16           1          012013-12-160000-00-00             5
# 4         2013-12-18           1          012013-12-180000-00-00             6
# 5         2014-05-29           1          012014-05-290000-00-00             7
# 6         2014-09-24           1          012014-09-240000-00-00             8
# 7         2014-10-03           1          012014-10-030000-00-00             9
# 8         2014-10-06           1          012014-10-060000-00-00            10
# 9         2014-12-11           1          012014-12-110000-00-00            11
# 10        2015-01-09           1          012015-01-090000-00-00            12
# 11        2015-02-01           1          012015-02-010000-00-00            13
# 12        2015-05-24           1          012015-05-240000-00-00            14
# 13        2015-08-24           1          012015-08-240000-00-00            15
# 14        2015-09-20           1          012015-09-200000-00-00            16
#
# [15 rows x 23 columns]

# %%
IO_TESTING and _patients.limit(10).toPandas()
# Out:
#   naaccrRecordVersion npiRegistryId patientIdNumber patientSystemIdHosp sex  \
# 0                 180                      00000037                       1
# 1                 180                      00000056                       2
# 2                 180                      00000041                       1
# 3                 180                      00000013                       2
# 4                 180                      00000068                       1
# 5                 180                      00000072                       2
# 6                 180                      00000103                       1
# 7                 180                      00000060                       2
# 8                 180                      00000061                       2
# 9                 180                      00000039                       1
#
#   dateOfBirth dateCaseReportExported dateOfLastContact vitalStatus
# 0  1947-03-30                   None        2018-11-23           1
# 1  1944-04-13                   None        2015-12-06           1
# 2  1942-01-24                   None        2018-09-06           1
# 3  1975-12-08                   None        2018-09-16           1
# 4  1950-08-30                   None        2014-05-29           1
# 5  1939-02-28                   None        2019-03-08           1
# 6  1965-01-09                   None        2016-11-13           1
# 7  1946-01-16                   None        2018-07-13           1
# 8  1974-10-10                   None        2017-07-16           1
# 9  1969-03-29                   None        2019-04-12           1

# %% [markdown]
# ##  Observations

# %%
def melt(df: DataFrame,
         id_vars: List[str], value_vars: List[str],
         var_name: str = 'variable', value_name: str = 'value') -> DataFrame:
    """Convert :class:`DataFrame` from wide to long format."""
    # ack: user6910411 Jan 2017 https://stackoverflow.com/a/41673644

    # Create array<struct<variable: str, value: ...>>
    _vars_and_vals = func.array(*(
        func.struct(func.lit(c).alias(var_name), func.col(c).alias(value_name))
        for c in value_vars))

    # Add to the DataFrame and explode
    _tmp = df.withColumn("_vars_and_vals", func.explode(_vars_and_vals))

    cols = [func.col(v) for v in id_vars] + [
        func.col("_vars_and_vals")[x].alias(x) for x in [var_name, value_name]]
    return _tmp.select(*cols)

# %%
if IO_TESTING:
    _ty = _spark.read.csv('heron_load/tumor_item_type.csv',
                          header=True, inferSchema=True)
    _ty.cache()
IO_TESTING and _ty.limit(5).toPandas()
# Out:
#    naaccrNum  sectionId                section               naaccrId  \
# 0        380          1  Cancer Identification  sequenceNumberCentral
# 1        390          1  Cancer Identification        dateOfDiagnosis
# 2        391          1  Cancer Identification    dateOfDiagnosisFlag
# 3        400          1  Cancer Identification            primarySite
# 4        410          1  Cancer Identification             laterality
#
#                  naaccrName  length    source loinc_num scale_typ  \
# 0  Sequence Number--Central       2      SEER   21853-7       Ord
# 1         Date of Diagnosis       8  SEER/CoC   21854-5        Qn
# 2    Date of Diagnosis Flag       2    NAACCR   59516-5       Nom
# 3              Primary Site       4  SEER/CoC   21855-2       Nom
# 4                Laterality       1  SEER/CoC      None       Nom
#
#   AnswerListId      scheme valtype_cd phi_id_kind
# 0      LL210-6        None          @        None
# 1         None        None          D        None
# 2      LL929-1        None          @        None
# 3         None        None          @        None
# 4         None  laterality          @        None

# %% [markdown]
# **ISSUE**: performance: whenever we change cardinality, consider persisting the data. e.g. stack_obs

# %%
def stack_obs(records: DataFrame, ty: DataFrame,
              known_valtype_cd: List[str] = ['@', 'D', 'N', 'Ni', 'T'],
              key_cols: List[str] = TumorKeys.key4 + TumorKeys.dtcols) -> DataFrame:
    ty = ty.select('naaccrNum', 'naaccrId', 'valtype_cd')
    ty = ty.where(ty.valtype_cd.isin(known_valtype_cd))
    value_vars = [row.naaccrId for row in ty.collect()]
    obs = melt(records, key_cols, value_vars, var_name='naaccrId', value_name='raw_value')
    obs = obs.where("trim(raw_value) != ''")
    obs = obs.join(ty, ty.naaccrId == obs.naaccrId).drop(ty.naaccrId)
    return obs


if IO_TESTING:
    _raw_obs = TumorKeys.with_tumor_id(naaccr_dates(stack_obs(_extract, _ty), TumorKeys.dtcols))
    _raw_obs.createOrReplaceTempView('naaccr_obs_raw')
IO_TESTING and _raw_obs.limit(10).toPandas()
# Out:
#   patientSystemIdHosp tumorRecordNumber patientIdNumber abstractedBy  \
# 0                                    01        00000010
# 1                                    01        00000010
# 2                                    01        00000010
# 3                                    01        00000010
# 4                                    01        00000010
# 5                                    01        00000010
# 6                                    01        00000010
# 7                                    01        00000010
# 8                                    01        00000010
# 9                                    01        00000010
#
#   dateOfBirth dateOfDiagnosis dateOfLastContact dateCaseCompleted  \
# 0  1951-04-05      2017-10-19        2017-10-19              None
# 1  1951-04-05      2017-10-19        2017-10-19              None
# 2  1951-04-05      2017-10-19        2017-10-19              None
# 3  1951-04-05      2017-10-19        2017-10-19              None
# 4  1951-04-05      2017-10-19        2017-10-19              None
# 5  1951-04-05      2017-10-19        2017-10-19              None
# 6  1951-04-05      2017-10-19        2017-10-19              None
# 7  1951-04-05      2017-10-19        2017-10-19              None
# 8  1951-04-05      2017-10-19        2017-10-19              None
# 9  1951-04-05      2017-10-19        2017-10-19              None
#
#   dateCaseLastChanged                naaccrId raw_value  naaccrNum valtype_cd  \
# 0                None   sequenceNumberCentral        00        380          @
# 1                None         dateOfDiagnosis  20171019        390          D
# 2                None             primarySite      C504        400          @
# 3                None              laterality         9        410          @
# 4                None                   grade         9        440          @
# 5                None        dateConclusiveDx  20171019        443          D
# 6                None     multTumRptAsOnePrim        99        444          @
# 7                None        dateOfMultTumors  20171019        445          D
# 8                None     multiplicityCounter        99        446          N
# 9                None  diagnosticConfirmation         1        490          @
#
#                          recordId
# 0          012017-10-190000-00-00
# 1          012017-10-190000-00-00
# 2          012017-10-190000-00-00
# 3          012017-10-190000-00-00
# 4          012017-10-190000-00-00
# 5          012017-10-190000-00-00
# 6          012017-10-190000-00-00
# 7          012017-10-190000-00-00
# 8          012017-10-190000-00-00
# 9          012017-10-190000-00-00

# %%
if IO_TESTING:
    _script1 = SqlScript('naaccr_txform.sql',
                         res.read_text(heron_load, 'naaccr_txform.sql'),
                         [('tumor_item_value', ['naaccr_obs_raw'])])
    create_objects(_spark, _script1, naaccr_obs_raw=_raw_obs)
IO_TESTING and _spark.table('tumor_item_value').limit(10).toPandas()
# Out:
# INFO:tumor_reg_ont:naaccr_txform.sql: naaccr_obs_raw = DataFrame[patientSystemIdHosp: string, tumorRecordNumber: string, patientIdNumber: string, abstractedBy: string, dateOfBirth: date, dateOfDiagnosis: date, dateOfLastContact: date, dateCaseCompleted: date, dateCaseLastChanged: date, naaccrId: string, raw_value: string, naaccrNum: int, valtype_cd: string, recordId: string]
# INFO:tumor_reg_ont:naaccr_txform.sql: create tumor_item_value
#   patientSystemIdHosp tumorRecordNumber patientIdNumber abstractedBy  \
# 0                                    01        00000010
# 1                                    01        00000010
# 2                                    01        00000010
# 3                                    01        00000010
# 4                                    01        00000010
# 5                                    01        00000010
# 6                                    01        00000010
# 7                                    01        00000010
# 8                                    01        00000010
# 9                                    01        00000010
#
#   dateOfBirth dateOfDiagnosis dateOfLastContact dateCaseCompleted  \
# 0  1951-04-05      2017-10-19        2017-10-19              None
# 1  1951-04-05      2017-10-19        2017-10-19              None
# 2  1951-04-05      2017-10-19        2017-10-19              None
# 3  1951-04-05      2017-10-19        2017-10-19              None
# 4  1951-04-05      2017-10-19        2017-10-19              None
# 5  1951-04-05      2017-10-19        2017-10-19              None
# 6  1951-04-05      2017-10-19        2017-10-19              None
# 7  1951-04-05      2017-10-19        2017-10-19              None
# 8  1951-04-05      2017-10-19        2017-10-19              None
# 9  1951-04-05      2017-10-19        2017-10-19              None
#
#   dateCaseLastChanged                naaccrId raw_value  naaccrNum valtype_cd  \
# 0                None   sequenceNumberCentral        00        380          @
# 1                None         dateOfDiagnosis  20171019        390          D
# 2                None             primarySite      C504        400          @
# 3                None              laterality         9        410          @
# 4                None                   grade         9        440          @
# 5                None        dateConclusiveDx  20171019        443          D
# 6                None     multTumRptAsOnePrim        99        444          @
# 7                None        dateOfMultTumors  20171019        445          D
# 8                None     multiplicityCounter        99        446          N
# 9                None  diagnosticConfirmation         1        490          @
#
#                          recordId  identified_only code_value  numeric_value  \
# 0          012017-10-190000-00-00            False         00            NaN
# 1          012017-10-190000-00-00            False       None            NaN
# 2          012017-10-190000-00-00            False       C504            NaN
# 3          012017-10-190000-00-00            False          9            NaN
# 4          012017-10-190000-00-00            False          9            NaN
# 5          012017-10-190000-00-00            False       None            NaN
# 6          012017-10-190000-00-00            False         99            NaN
# 7          012017-10-190000-00-00            False       None            NaN
# 8          012017-10-190000-00-00            False       None           99.0
# 9          012017-10-190000-00-00            False          1            NaN
#
#    date_value text_value
# 0        None       None
# 1  2017-10-19       None
# 2        None       None
# 3        None       None
# 4        None       None
# 5  2017-10-19       None
# 6        None       None
# 7  2017-10-19       None
# 8        None       None
# 9        None       None

# %%
if IO_TESTING:
    _script1 = SqlScript('naaccr_txform.sql',
                         res.read_text(heron_load, 'naaccr_txform.sql'),
                         [('tumor_reg_facts', ['record_layout', 'section'])])
    create_objects(_spark, _script1,
                   record_layout=_spark.createDataFrame(NAACCR_Layout.fields),
                   section=_spark.createDataFrame(NAACCR_I2B2.per_section))
IO_TESTING and _spark.table('tumor_reg_facts').limit(10).toPandas()
# Out:
# INFO:tumor_reg_ont:naaccr_txform.sql: record_layout = DataFrame[end: bigint, length: bigint, naaccr-item-num: bigint, name: string, section: string, start: bigint]
# INFO:tumor_reg_ont:naaccr_txform.sql: section = DataFrame[sectionid: bigint, section: string]
# INFO:tumor_reg_ont:naaccr_txform.sql: create tumor_reg_facts
#                          recordId patientIdNumber      naaccrId  \
# 0          012017-10-190000-00-00        00000010  causeOfDeath
# 1          012018-07-100000-00-00        00000011  causeOfDeath
# 2          012013-12-160000-00-00        00000012  causeOfDeath
# 3          012018-09-160000-00-00        00000013  causeOfDeath
# 4          012017-03-280000-00-00        00000014  causeOfDeath
# 5          012017-09-020000-00-00        00000015  causeOfDeath
# 6          012010-04-250000-00-00        00000016  causeOfDeath
# 7          012016-11-050000-00-00        00000017  causeOfDeath
# 8          012018-04-200000-00-00        00000018  causeOfDeath
# 9          012017-02-100000-00-00        00000019  causeOfDeath
#
#          concept_cd provider_id  start_date modifier_cd  instance_num  \
# 0  NAACCR|1910:0000           @  2017-10-19           @             1
# 1  NAACCR|1910:0000           @  2018-07-10           @             1
# 2  NAACCR|1910:0000           @  2013-12-16           @             1
# 3  NAACCR|1910:0000           @  2018-09-16           @             1
# 4  NAACCR|1910:0000           @  2017-03-28           @             1
# 5  NAACCR|1910:0000           @  2017-09-02           @             1
# 6  NAACCR|1910:0000           @  2010-04-25           @             1
# 7  NAACCR|1910:0000           @  2016-11-05           @             1
# 8  NAACCR|1910:0000           @  2018-04-20           @             1
# 9  NAACCR|1910:0000           @  2017-02-10           @             1
#
#   valtype_cd tval_char nval_num valueflag_cd units_cd    end_date location_cd  \
# 0          @      None     None         None     None  2017-10-19           @
# 1          @      None     None         None     None  2018-07-10           @
# 2          @      None     None         None     None  2013-12-16           @
# 3          @      None     None         None     None  2018-09-16           @
# 4          @      None     None         None     None  2017-03-28           @
# 5          @      None     None         None     None  2017-09-02           @
# 6          @      None     None         None     None  2010-04-25           @
# 7          @      None     None         None     None  2016-11-05           @
# 8          @      None     None         None     None  2018-04-20           @
# 9          @      None     None         None     None  2017-02-10           @
#
#   update_date
# 0  2017-10-19
# 1  2018-07-10
# 2  2013-12-16
# 3  2018-09-16
# 4  2017-03-28
# 5  2017-09-02
# 6  2010-04-25
# 7  2016-11-05
# 8  2018-04-20
# 9  2017-02-10

# %%
IO_TESTING and _spark.table('tumor_reg_facts').where("valtype_cd != '@'").limit(5).toPandas()
# Out:
#                          recordId patientIdNumber           naaccrId  \
# 0          012017-10-190000-00-00        00000010  dateOfLastContact
# 1          012018-07-100000-00-00        00000011  dateOfLastContact
# 2          012013-12-160000-00-00        00000012  dateOfLastContact
# 3          012018-09-160000-00-00        00000013  dateOfLastContact
# 4          012017-03-280000-00-00        00000014  dateOfLastContact
#
#      concept_cd provider_id  start_date modifier_cd  instance_num valtype_cd  \
# 0  NAACCR|1750:           @  2017-10-19           @             1          D
# 1  NAACCR|1750:           @  2018-07-10           @             1          D
# 2  NAACCR|1750:           @  2013-12-16           @             1          D
# 3  NAACCR|1750:           @  2018-09-16           @             1          D
# 4  NAACCR|1750:           @  2017-03-28           @             1          D
#
#     tval_char nval_num valueflag_cd units_cd    end_date location_cd  \
# 0  2017-10-19     None         None     None  2017-10-19           @
# 1  2018-07-10     None         None     None  2018-07-10           @
# 2  2013-12-16     None         None     None  2013-12-16           @
# 3  2018-09-16     None         None     None  2018-09-16           @
# 4  2017-03-28     None         None     None  2017-03-28           @
#
#   update_date
# 0  2017-10-19
# 1  2018-07-10
# 2  2013-12-16
# 3  2018-09-16
# 4  2017-03-28

# %%
class ItemObs:
    script = SqlScript('naaccr_txform.sql',
                       res.read_text(heron_load, 'naaccr_txform.sql'),
                       [
                           ('tumor_item_value', ['naaccr_obs_raw']),
                           ('tumor_reg_facts', ['record_layout', 'section']),
                       ])

    extract_id_view = 'naaccr_extract_id'

    @classmethod
    def make(cls, spark: SparkSession_T, extract: DataFrame) -> DataFrame:
        item_ty = NAACCR_I2B2.item_views_in(spark)

        raw_obs = TumorKeys.with_tumor_id(naaccr_dates(
            stack_obs(extract, item_ty),
            TumorKeys.dtcols))

        views = create_objects(
            spark, cls.script,
            naaccr_obs_raw=raw_obs,
            # ISSUE: refactor item_views_in
            record_layout=spark.createDataFrame(NAACCR_Layout.fields),
            section=spark.createDataFrame(NAACCR_I2B2.per_section))

        return list(views.values())[-1]

    @classmethod
    def make_extract_id(cls,
                        spark: SparkSession_T,
                        extract: DataFrame) -> DataFrame:
        extract_id = TumorKeys.with_tumor_id(
            naaccr_dates(extract, TumorKeys.dtcols))
        extract_id.createOrReplaceTempView(cls.extract_id_view)
        return spark.table(cls.extract_id_view)


if IO_TESTING:
    _obs = ItemObs.make(_spark, _extract)
IO_TESTING and _obs.limit(5).toPandas()
# Out:
# INFO:tumor_reg_ont:naaccr_txform.sql: naaccr_obs_raw = DataFrame[patientSystemIdHosp: string, tumorRecordNumber: string, patientIdNumber: string, abstractedBy: string, dateOfBirth: date, dateOfDiagnosis: date, dateOfLastContact: date, dateCaseCompleted: date, dateCaseLastChanged: date, naaccrId: string, raw_value: string, naaccrNum: bigint, valtype_cd: string, recordId: string]
# INFO:tumor_reg_ont:naaccr_txform.sql: record_layout = DataFrame[end: bigint, length: bigint, naaccr-item-num: bigint, name: string, section: string, start: bigint]
# INFO:tumor_reg_ont:naaccr_txform.sql: section = DataFrame[sectionid: bigint, section: string]
# INFO:tumor_reg_ont:naaccr_txform.sql: create tumor_item_value
# INFO:tumor_reg_ont:naaccr_txform.sql: create tumor_reg_facts
#                          recordId patientIdNumber      naaccrId  \
# 0          012016-11-130000-00-00        00000103  causeOfDeath
# 1          012015-02-010000-00-00        00000102  causeOfDeath
# 2          012017-11-230000-00-00        00000101  causeOfDeath
# 3          012018-09-110000-00-00        00000100  causeOfDeath
# 4          012017-10-040000-00-00        00000099  causeOfDeath
#
#          concept_cd provider_id  start_date modifier_cd  instance_num  \
# 0  NAACCR|1910:0000           @  2016-11-13           @             1
# 1  NAACCR|1910:0000           @  2015-02-01           @             1
# 2  NAACCR|1910:0000           @  2017-11-23           @             1
# 3  NAACCR|1910:0000           @  2018-09-11           @             1
# 4  NAACCR|1910:0000           @  2017-10-04           @             1
#
#   valtype_cd tval_char nval_num valueflag_cd units_cd    end_date location_cd  \
# 0          @      None     None         None     None  2016-11-13           @
# 1          @      None     None         None     None  2015-02-01           @
# 2          @      None     None         None     None  2017-11-23           @
# 3          @      None     None         None     None  2018-09-11           @
# 4          @      None     None         None     None  2017-10-04           @
#
#   update_date
# 0  2016-11-13
# 1  2015-02-01
# 2  2017-11-23
# 3  2018-09-11
# 4  2017-10-04

# %%
IO_TESTING and ItemObs.make_extract_id(_spark, _extract).limit(5).toPandas()
# Out:
#   recordType registryType naaccrRecordVersion npiRegistryId  registryId  \
# 0          I                              180
# 1          I                              180
# 2          I                              180
# 3          I                              180
# 4          I                              180
#
#   tumorRecordNumber patientIdNumber patientSystemIdHosp  \
# 0                01        00000010
# 1                01        00000011
# 2                01        00000012
# 3                01        00000013
# 4                01        00000014
#
#                                         addrAtDxCity addrAtDxState  ...  \
# 0                                                ...                ...
# 1                                                ...                ...
# 2                                                ...                ...
# 3                                                ...                ...
# 4                                                ...                ...
#
#   rxTextSurgery rxTextRadiation rxTextRadiationOther rxTextChemo  \
# 0
# 1
# 2
# 3
# 4
#
#   rxTextHormone rxTextBrm rxTextOther textRemarks textPlaceOfDiagnosis  \
# 0
# 1
# 2
# 3
# 4
#
#                          recordId
# 0          012017-10-190000-00-00
# 1          012018-07-100000-00-00
# 2          012013-12-160000-00-00
# 3          012018-09-160000-00-00
# 4          012017-03-280000-00-00
#
# [5 rows x 773 columns]

# %% [markdown]
# ## SEER Site Recode

# %%
class SEER_Recode:
    script = SqlScript('seer_recode.sql',
                       res.read_text(heron_load, 'seer_recode.sql'),
                       [('seer_recode_aux', ['naaccr_extract_id']),
                        ('seer_recode_facts', [])])

    @classmethod
    def make(cls, spark: SparkSession_T, extract: DataFrame) -> DataFrame:
        extract_id = ItemObs.make_extract_id(spark, extract)
        views = create_objects(spark, cls.script,
                               naaccr_extract_id=extract_id)
        return list(views.values())[-1]


IO_TESTING and SEER_Recode.make(_spark, _extract).limit(5).toPandas()
# Out:
# INFO:tumor_reg_ont:seer_recode.sql: naaccr_extract_id = DataFrame[recordType: string, registryType: string, naaccrRecordVersion: string, npiRegistryId: string, registryId: string, tumorRecordNumber: string, patientIdNumber: string, patientSystemIdHosp: string, addrAtDxCity: string, addrAtDxState: string, addrAtDxPostalCode: string, countyAtDx: string, countyAtDxAnalysis: string, stateAtDxGeocode19708090: string, countyAtDxGeocode1990: string, censusTract19708090: string, censusBlockGrp197090: string, censusCodSys19708090: string, censusTrCert19708090: string, stateAtDxGeocode2000: string, countyAtDxGeocode2000: string, censusTract2000: string, censusBlockGroup2000: string, censusTrCertainty2000: string, stateAtDxGeocode2010: string, countyAtDxGeocode2010: string, censusTract2010: string, censusBlockGroup2010: string, censusTrCertainty2010: string, stateAtDxGeocode2020: string, countyAtDxGeocode2020: string, censusTract2020: string, censusBlockGroup2020: string, censusTractCertainty2020: string, maritalStatusAtDx: string, race1: string, race2: string, race3: string, race4: string, race5: string, raceCodingSysCurrent: string, raceCodingSysOriginal: string, spanishHispanicOrigin: string, computedEthnicity: string, computedEthnicitySource: string, sex: string, ageAtDiagnosis: string, dateOfBirth: date, dateOfBirthFlag: string, birthplace: string, censusOccCode19702000: string, censusIndCode19702000: string, occupationSource: string, industrySource: string, textUsualOccupation: string, textUsualIndustry: string, censusOccIndSys7000: string, nhiaDerivedHispOrigin: string, raceNapiia: string, ihsLink: string, gisCoordinateQuality: string, ruralurbanContinuum1993: string, ruralurbanContinuum2003: string, ruralurbanContinuum2013: string, ruca2000: string, ruca2010: string, uric2000: string, uric2010: string, addrAtDxCountry: string, addrCurrentCountry: string, birthplaceState: string, birthplaceCountry: string, followupContactCountry: string, placeOfDeathState: string, placeOfDeathCountry: string, censusIndCode2010: string, censusOccCode2010: string, censusTrPovertyIndictr: string, sequenceNumberCentral: string, dateOfDiagnosis: date, dateOfDiagnosisFlag: string, primarySite: string, laterality: string, histologyIcdO2: string, behaviorIcdO2: string, histologicTypeIcdO3: string, behaviorCodeIcdO3: string, grade: string, gradePathValue: string, gradePathSystem: string, siteCodingSysCurrent: string, siteCodingSysOriginal: string, morphCodingSysCurrent: string, morphCodingSysOriginl: string, diagnosticConfirmation: string, typeOfReportingSource: string, casefindingSource: string, ambiguousTerminologyDx: string, dateConclusiveDx: string, dateConclusiveDxFlag: string, multTumRptAsOnePrim: string, dateOfMultTumors: string, dateOfMultTumorsFlag: string, multiplicityCounter: string, npiReportingFacility: string, reportingFacility: string, npiArchiveFin: string, archiveFin: string, accessionNumberHosp: string, sequenceNumberHospital: string, abstractedBy: string, dateOf1stContact: string, dateOf1stContactFlag: string, dateOfInptAdm: string, dateOfInptAdmFlag: string, dateOfInptDisch: string, dateOfInptDischFlag: string, inpatientStatus: string, classOfCase: string, primaryPayerAtDx: string, rxHospSurgApp2010: string, rxHospSurgPrimSite: string, rxHospScopeRegLnSur: string, rxHospSurgOthRegDis: string, rxHospRegLnRemoved: string, rxHospRadiation: string, rxHospChemo: string, rxHospHormone: string, rxHospBrm: string, rxHospOther: string, rxHospDxStgProc: string, rxHospPalliativeProc: string, rxHospSurgSite9802: string, rxHospScopeReg9802: string, rxHospSurgOth9802: string, tnmPathStagedBy: string, tnmClinStagedBy: string, metsAtDxBone: string, metsAtDxBrain: string, metsAtDxDistantLn: string, metsAtDxLiver: string, metsAtDxLung: string, metsAtDxOther: string, tumorSizeClinical: string, tumorSizePathologic: string, tumorSizeSummary: string, derivedSeerPathStgGrp: string, derivedSeerClinStgGrp: string, derivedSeerCmbStgGrp: string, derivedSeerCombin ...
# INFO:tumor_reg_ont:seer_recode.sql: create seer_recode_aux
# INFO:tumor_reg_ont:seer_recode.sql: create seer_recode_facts
#                          recordId patientIdNumber naaccrId       concept_cd  \
# 0          012017-10-190000-00-00        00000010        @  SEER_SITE:26000
# 1          012018-07-100000-00-00        00000011        @  SEER_SITE:22030
# 2          012013-12-160000-00-00        00000012        @  SEER_SITE:21052
# 3          012018-09-160000-00-00        00000013        @  SEER_SITE:20050
# 4          012017-03-280000-00-00        00000014        @  SEER_SITE:29010
#
#   provider_id  start_date modifier_cd  instance_num valtype_cd tval_char  \
# 0           @  2017-10-19           @             1          @         @
# 1           @  2018-07-10           @             1          @         @
# 2           @  2013-12-16           @             1          @         @
# 3           @  2018-09-16           @             1          @         @
# 4           @  2017-03-28           @             1          @         @
#
#   nval_num valueflag_cd units_cd    end_date location_cd update_date
# 0     None         None     None  2017-10-19           @  2017-10-19
# 1     None         None     None  2018-07-10           @  2018-07-10
# 2     None         None     None  2013-12-16           @  2013-12-16
# 3     None         None     None  2018-09-16           @  2018-09-16
# 4     None         None     None  2017-03-28           @  2017-03-28

# %%
class SiteSpecificFactors:
    sql = res.read_text(heron_load, 'csschema.sql')
    script1 = SqlScript('csschema.sql', sql,
                        [('tumor_cs_schema', ['naaccr_extract_id'])])
    script2 = SqlScript('csschema.sql', sql,
                        [('cs_site_factor_facts', ['cs_obs_raw'])])

    items = [it for it in NAACCR1.items_180()
             if it['naaccrName'].startswith('CS Site-Specific Factor')]

    @classmethod
    def valtypes(cls) -> pd.DataFrame:
        factor_nums = [d['naaccrNum'] for d in cls.items]
        item_ty = NAACCR_I2B2.tumor_item_type[['naaccrNum', 'naaccrId', 'valtype_cd']]
        item_ty = item_ty[item_ty.naaccrNum.isin(factor_nums)]
        return item_ty

    @classmethod
    def make(cls, spark: SparkSession_T, extract: DataFrame) -> DataFrame:
        with_schema = cls.make_tumor_schema(spark, extract)
        ty_df = spark.createDataFrame(cls.valtypes())

        raw_obs = stack_obs(with_schema, ty_df,
                            key_cols=TumorKeys.key4 + TumorKeys.dtcols + ['recordId', 'cs_schema_name'])

        views = create_objects(spark, cls.script2,
                               cs_obs_raw=raw_obs)
        return list(views.values())[-1]

    @classmethod
    def make_tumor_schema(cls,
                          spark: SparkSession_T,
                          extract: DataFrame) -> DataFrame:
        views = create_objects(spark, cls.script1,
                               naaccr_extract_id=ItemObs.make_extract_id(spark, extract))
        return list(views.values())[-1]


if IO_TESTING:
    _ssf_facts = SiteSpecificFactors.make(_spark, _extract)
    assert _obs.columns == _ssf_facts.columns

IO_TESTING and _ssf_facts.limit(7).toPandas()
# Out:
# INFO:tumor_reg_ont:csschema.sql: naaccr_extract_id = DataFrame[recordType: string, registryType: string, naaccrRecordVersion: string, npiRegistryId: string, registryId: string, tumorRecordNumber: string, patientIdNumber: string, patientSystemIdHosp: string, addrAtDxCity: string, addrAtDxState: string, addrAtDxPostalCode: string, countyAtDx: string, countyAtDxAnalysis: string, stateAtDxGeocode19708090: string, countyAtDxGeocode1990: string, censusTract19708090: string, censusBlockGrp197090: string, censusCodSys19708090: string, censusTrCert19708090: string, stateAtDxGeocode2000: string, countyAtDxGeocode2000: string, censusTract2000: string, censusBlockGroup2000: string, censusTrCertainty2000: string, stateAtDxGeocode2010: string, countyAtDxGeocode2010: string, censusTract2010: string, censusBlockGroup2010: string, censusTrCertainty2010: string, stateAtDxGeocode2020: string, countyAtDxGeocode2020: string, censusTract2020: string, censusBlockGroup2020: string, censusTractCertainty2020: string, maritalStatusAtDx: string, race1: string, race2: string, race3: string, race4: string, race5: string, raceCodingSysCurrent: string, raceCodingSysOriginal: string, spanishHispanicOrigin: string, computedEthnicity: string, computedEthnicitySource: string, sex: string, ageAtDiagnosis: string, dateOfBirth: date, dateOfBirthFlag: string, birthplace: string, censusOccCode19702000: string, censusIndCode19702000: string, occupationSource: string, industrySource: string, textUsualOccupation: string, textUsualIndustry: string, censusOccIndSys7000: string, nhiaDerivedHispOrigin: string, raceNapiia: string, ihsLink: string, gisCoordinateQuality: string, ruralurbanContinuum1993: string, ruralurbanContinuum2003: string, ruralurbanContinuum2013: string, ruca2000: string, ruca2010: string, uric2000: string, uric2010: string, addrAtDxCountry: string, addrCurrentCountry: string, birthplaceState: string, birthplaceCountry: string, followupContactCountry: string, placeOfDeathState: string, placeOfDeathCountry: string, censusIndCode2010: string, censusOccCode2010: string, censusTrPovertyIndictr: string, sequenceNumberCentral: string, dateOfDiagnosis: date, dateOfDiagnosisFlag: string, primarySite: string, laterality: string, histologyIcdO2: string, behaviorIcdO2: string, histologicTypeIcdO3: string, behaviorCodeIcdO3: string, grade: string, gradePathValue: string, gradePathSystem: string, siteCodingSysCurrent: string, siteCodingSysOriginal: string, morphCodingSysCurrent: string, morphCodingSysOriginl: string, diagnosticConfirmation: string, typeOfReportingSource: string, casefindingSource: string, ambiguousTerminologyDx: string, dateConclusiveDx: string, dateConclusiveDxFlag: string, multTumRptAsOnePrim: string, dateOfMultTumors: string, dateOfMultTumorsFlag: string, multiplicityCounter: string, npiReportingFacility: string, reportingFacility: string, npiArchiveFin: string, archiveFin: string, accessionNumberHosp: string, sequenceNumberHospital: string, abstractedBy: string, dateOf1stContact: string, dateOf1stContactFlag: string, dateOfInptAdm: string, dateOfInptAdmFlag: string, dateOfInptDisch: string, dateOfInptDischFlag: string, inpatientStatus: string, classOfCase: string, primaryPayerAtDx: string, rxHospSurgApp2010: string, rxHospSurgPrimSite: string, rxHospScopeRegLnSur: string, rxHospSurgOthRegDis: string, rxHospRegLnRemoved: string, rxHospRadiation: string, rxHospChemo: string, rxHospHormone: string, rxHospBrm: string, rxHospOther: string, rxHospDxStgProc: string, rxHospPalliativeProc: string, rxHospSurgSite9802: string, rxHospScopeReg9802: string, rxHospSurgOth9802: string, tnmPathStagedBy: string, tnmClinStagedBy: string, metsAtDxBone: string, metsAtDxBrain: string, metsAtDxDistantLn: string, metsAtDxLiver: string, metsAtDxLung: string, metsAtDxOther: string, tumorSizeClinical: string, tumorSizePathologic: string, tumorSizeSummary: string, derivedSeerPathStgGrp: string, derivedSeerClinStgGrp: string, derivedSeerCmbStgGrp: string, derivedSeerCombinedT ...
# INFO:tumor_reg_ont:csschema.sql: create tumor_cs_schema
# INFO:tumor_reg_ont:csschema.sql: cs_obs_raw = DataFrame[patientSystemIdHosp: string, tumorRecordNumber: string, patientIdNumber: string, abstractedBy: string, dateOfBirth: date, dateOfDiagnosis: date, dateOfLastContact: date, dateCaseCompleted: date, dateCaseLastChanged: date, recordId: string, cs_schema_name: string, naaccrId: string, raw_value: string, naaccrNum: bigint, valtype_cd: string]
# INFO:tumor_reg_ont:csschema.sql: create cs_site_factor_facts
#                          recordId patientIdNumber naaccrId  \
# 0          012015-02-010000-00-00        00000102        @
# 1          012014-12-110000-00-00        00000095        @
# 2          012015-08-240000-00-00        00000075        @
# 3          012014-05-290000-00-00        00000068        @
# 4          022013-05-030000-00-00        00000065        @
# 5          012014-10-060000-00-00        00000062        @
# 6          012014-09-240000-00-00        00000059        @
#
#               concept_cd provider_id  start_date modifier_cd  instance_num  \
# 0        CS|Testis|7:999           @  2015-02-01           @             1
# 1          CS|Skin|7:999           @  2014-12-11           @             1
# 2          CS|Lung|7:988           @  2015-08-24           @             1
# 3      CS|Prostate|7:054           @  2014-05-29           @             1
# 4  CS|ParotidGland|7:020           @  2013-05-03           @             1
# 5        CS|Rectum|7:050           @  2014-10-06           @             1
# 6      CS|Lymphoma|7:988           @  2014-09-24           @             1
#
#   valtype_cd tval_char nval_num valueflag_cd units_cd    end_date location_cd  \
# 0          @      None     None         None     None  2015-02-01           @
# 1          @      None     None         None     None  2014-12-11           @
# 2          @      None     None         None     None  2015-08-24           @
# 3          @      None     None         None     None  2014-05-29           @
# 4          @      None     None         None     None  2013-05-03           @
# 5          @      None     None         None     None  2014-10-06           @
# 6          @      None     None         None     None  2014-09-24           @
#
#   update_date
# 0  2015-02-01
# 1  2014-12-11
# 2  2015-08-24
# 3  2014-05-29
# 4  2013-05-03
# 5  2014-10-06
# 6  2014-09-24

# %% [markdown]
# ## Oracle DB Access

# %% [markdown]
# We use `PYSPARK_SUBMIT_ARGS` to get JDBC jar in both
# `spark.driver.extraClassPath` and `--jars`:

# %%
if IO_TESTING:
    from os import environ as _environ
    log.info(_environ['PYSPARK_SUBMIT_ARGS'])
# Out:
# INFO:__main__:--driver-class-path /home/dconnolly/Downloads/ojdbc8.jar --jars /home/dconnolly/Downloads/ojdbc8.jar

# %%
IO_TESTING and _spark.sparkContext.getConf().get('spark.driver.extraClassPath')

# %%
if IO_TESTING:
    def _set_pw(name: str = 'ID CDW') -> None:
        from os import environ
        from getpass import getpass
        password = getpass(name)
        environ[name] = password

    # _set_pw()

# %%
class Account:
    def __init__(self, user: str, password: str,
                 url: str = 'jdbc:oracle:thin:@localhost:8621:nheronB2',
                 driver: str = "oracle.jdbc.OracleDriver") -> None:
        self.url = url
        db = url.split(':')[-1]
        self.label = f'{self.__class__.__name__}({user}@{db})'
        self.__properties = {"user": user,
                             "password": password,
                             "driver": driver}

    def __repr__(self) -> str:
        return self.label

    def rd(self, io: sq.DataFrameReader, table: str) -> DataFrame:
        return io.jdbc(self.url, table,
                       properties=self.__properties)

    def wr(self, io: sq.DataFrameWriter, table: str,
           mode: Opt[str] = None) -> None:
        io.jdbc(self.url, table,
                properties=self.__properties,
                mode=mode)


DB_TESTING = IO_TESTING and 'ID CDW' in _environ
if DB_TESTING:
    _cdw = Account(_environ['LOGNAME'], _environ['ID CDW'])

DB_TESTING and _cdw.rd(_spark.read, "global_name").toPandas()
# Out:
# False

# %% [markdown]
#   - **ISSUE**: column name capitalization: `concept_cd` vs.
#     `CONCEPT_CD`, `dateOfDiagnosis` vs. `DATEOFDIAGNOSIS`
#     vs. `DATE_OF_DIAGNOSIS`.

# %%
def case_fold(df: DataFrame) -> DataFrame:
    """Fold column names to upper-case, following (Oracle) SQL norms.

    See also: upper_snake_case in pcornet_cdm
    """
    return df.toDF(*[n.upper() for n in df.columns])

# %%
if DB_TESTING:
    _patients_mapped = TumorKeys.with_patient_num(_patients, _spark, _cdw, 'NIGHTHERONDATA', 'SMS@kumed.com')

DB_TESTING and _patients_mapped.limit(5).toPandas()
# Out:
# False

# %% [markdown]
# ## Use Case: GPC Breast Cancer Survey
#
# The NAACCR format has 500+ items. To provide initial focus, let's use
# the variables from the 2016 GPC breast cancer survey:

# %%
class CancerStudy:
    bc_variable = pd.read_csv(res.open_text(bc_qa, 'bc-variable.csv'))


IO_TESTING and _spark.createDataFrame(
    CancerStudy.bc_variable).limit(5).toPandas()
# Out:
#    id                                           item_key  \
# 0   0        \\KUMC_naaccr\i2b2\naaccr\SEER Site\Breast\
# 1   1  \\KUMC_naaccr\i2b2\naaccr\S:6 Hospital-Specifi...
# 2   2  \\KUMC_naaccr\i2b2\naaccr\S:6 Hospital-Specifi...
# 3   3  \\KUMC_naaccr\i2b2\naaccr\S:6 Hospital-Specifi...
# 4   4  \\KUMC_naaccr\i2b2\naaccr\S:6 Hospital-Specifi...
#
#                                         concept_path  \
# 0                     \i2b2\naaccr\SEER Site\Breast\
# 1  \i2b2\naaccr\S:6 Hospital-Specific\0610 Class ...
# 2  \i2b2\naaccr\S:6 Hospital-Specific\0610 Class ...
# 3  \i2b2\naaccr\S:6 Hospital-Specific\0610 Class ...
# 4  \i2b2\naaccr\S:6 Hospital-Specific\0610 Class ...
#
#                                name_char     name
# 0  Breast [10,281 facts; 9,729 patients]  Breast
# 1            30  [58 facts; 58 patients]     30
# 2                     31  [&lt;10 facts]     31
# 3    32  [14,310 facts; 14,026 patients]     32
# 4                     33  [&lt;10 facts]     33

# %%
def itemNumOfPath(bc_var: DataFrame,
                  item: str = 'item') -> DataFrame:
    digits = func.regexp_extract('concept_path',
                                 r'\\i2b2\\naaccr\\S:[^\\]+\\(\d+)', 1)
    items = bc_var.select(digits.cast('int').alias(item))   # TODO: .dropna().distinct()
    return items.sort(item)


IO_TESTING and itemNumOfPath(_spark.createDataFrame(
    CancerStudy.bc_variable)).limit(5).toPandas()
# Out:
#     item
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4  160.0

# %%
def _selectedItems(ddict: DataFrame, items: DataFrame) -> DataFrame:
    selected = ddict.join(items,
                          ddict.naaccrNum == items.item).drop(items.item)
    return selected.sort(selected.length.desc(), selected.naaccrNum)


if IO_TESTING:
    _bc_ddict = _selectedItems(
        ddictDF(_spark),
        itemNumOfPath(_spark.createDataFrame(CancerStudy.bc_variable)),
    ).select('naaccrId', 'naaccrNum', 'parentXmlElement', 'length')

IO_TESTING and (
    _bc_ddict.select('naaccrId', 'naaccrNum', 'parentXmlElement', 'length')
    .toPandas().set_index(['naaccrNum', 'naaccrId'])
)
# Out:
#                                  parentXmlElement  length
# naaccrNum naaccrId
# 240       dateOfBirth                     Patient       8
# 390       dateOfDiagnosis                   Tumor       8
# 1750      dateOfLastContact               Patient       8
# 1860      recurrenceDate1st                 Tumor       8
# 400       primarySite                       Tumor       4
# 2869      csSiteSpecificFactor15            Tumor       3
# 2876      csSiteSpecificFactor22            Tumor       3
# 2877      csSiteSpecificFactor23            Tumor       3
# 2880      csSiteSpecificFactor1             Tumor       3
# 2890      csSiteSpecificFactor2             Tumor       3
# 3400      derivedAjcc7T                     Tumor       3
# 3430      derivedAjcc7StageGrp              Tumor       3
# 160       race1                           Patient       2
# 161       race2                           Patient       2
# 162       race3                           Patient       2
# 163       race4                           Patient       2
# 164       race5                           Patient       2
# 380       sequenceNumberCentral             Tumor       2
# 560       sequenceNumberHospital            Tumor       2
# 610       classOfCase                       Tumor       2
#           classOfCase                       Tumor       2
#           classOfCase                       Tumor       2
#           classOfCase                       Tumor       2
#           classOfCase                       Tumor       2
#           classOfCase                       Tumor       2
#           classOfCase                       Tumor       2
#           classOfCase                       Tumor       2
#           classOfCase                       Tumor       2
#           classOfCase                       Tumor       2
# 670       rxHospSurgPrimSite                Tumor       2
# 820       regionalNodesPositive             Tumor       2
# 830       regionalNodesExamined             Tumor       2
# 1861      recurrenceDate1stFlag             Tumor       2
# 2850      csMetsAtDx                        Tumor       2
# 2940      derivedAjcc6T                     Tumor       2
# 3000      derivedAjcc6StageGrp              Tumor       2
# 170       raceCodingSysCurrent            Patient       1
# 180       raceCodingSysOriginal           Patient       1
# 190       spanishHispanicOrigin           Patient       1
# 220       sex                             Patient       1
# 410       laterality                        Tumor       1
# 440       grade                             Tumor       1
# 490       diagnosticConfirmation            Tumor       1
# 1760      vitalStatus                     Patient       1
# 1770      cancerStatus                      Tumor       1
# 2860      csMetsEval                        Tumor       1
# 3020      derivedSs2000                     Tumor       1

# %% [markdown]
# ### Patients, Encounters, and Observations per Variable
#
#   - **ISSUE**: naaccr-xml test data has no data on classOfCase etc.
#     at least not the 100 tumor sample.

# %%
def bc_var_facts(coded_facts: DataFrame, ddict: DataFrame) -> DataFrame:
    return coded_facts.join(
        ddict.select('naaccrId'),
        coded_facts.naaccrId == ddict.naaccrId,
    ).drop(ddict.naaccrId)


def data_summary(spark: SparkSession_T, obs: DataFrame) -> DataFrame:
    obs.createOrReplaceTempView('summary_input')  # ISSUE: CLOBBER!
    return spark.sql('''
    select naaccrId as variable
         , count(distinct patientIdNumber) as pat_qty
         , count(distinct recordId) as enc_qty
         , count(*) as fact_qty
    from summary_input
    group by naaccrId
    order by 2 desc, 3 desc, 4 desc
    ''')


def bc_var_summary(spark: SparkSession_T,
                   obs: DataFrame, ddict: DataFrame) -> DataFrame:
    agg = data_summary(
        spark,
        bc_var_facts(obs, ddict)
    )
    dd = ddict.select('naaccrId').withColumnRenamed('naaccrId', 'variable')
    return (dd
            .join(agg, dd.variable == agg.variable, how='left_outer')
            .drop(agg.variable))


IO_TESTING and bc_var_summary(
    _spark, _obs, _bc_ddict).where(
        'fact_qty is null').toPandas()
# Out:
#                   variable variable pat_qty enc_qty fact_qty
# 0              classOfCase     None    None    None     None
# 1              classOfCase     None    None    None     None
# 2              classOfCase     None    None    None     None
# 3              classOfCase     None    None    None     None
# 4              classOfCase     None    None    None     None
# 5              classOfCase     None    None    None     None
# 6              classOfCase     None    None    None     None
# 7              classOfCase     None    None    None     None
# 8              classOfCase     None    None    None     None
# 9              classOfCase     None    None    None     None
# 10   regionalNodesExamined     None    None    None     None
# 11            cancerStatus     None    None    None     None
# 12      rxHospSurgPrimSite     None    None    None     None
# 13    derivedAjcc6StageGrp     None    None    None     None
# 14             dateOfBirth     None    None    None     None
# 15   regionalNodesPositive     None    None    None     None
# 16    derivedAjcc7StageGrp     None    None    None     None
# 17       recurrenceDate1st     None    None    None     None
# 18    raceCodingSysCurrent     None    None    None     None
# 19   raceCodingSysOriginal     None    None    None     None
# 20   recurrenceDate1stFlag     None    None    None     None
# 21  sequenceNumberHospital     None    None    None     None

# %%
IO_TESTING and bc_var_summary(
    _spark, _obs, _bc_ddict).where(
        'fact_qty is not null').toPandas()
# Out:
#                   variable                variable  pat_qty  enc_qty  fact_qty
# 0    csSiteSpecificFactor2   csSiteSpecificFactor2       18       18        18
# 1            derivedAjcc6T           derivedAjcc6T       17       17        17
# 2                    race4                   race4       94      100       100
# 3               csMetsAtDx              csMetsAtDx       18       18        18
# 4   csSiteSpecificFactor23  csSiteSpecificFactor23       18       18        18
# 5                    grade                   grade       94      100       100
# 6    csSiteSpecificFactor1   csSiteSpecificFactor1       18       18        18
# 7               csMetsEval              csMetsEval       18       18        18
# 8            derivedAjcc7T           derivedAjcc7T       16       16        16
# 9              primarySite             primarySite       94      100       100
# 10   spanishHispanicOrigin   spanishHispanicOrigin       94      100       100
# 11             vitalStatus             vitalStatus       94      100       100
# 12         dateOfDiagnosis         dateOfDiagnosis       94      100       100
# 13                   race5                   race5       94      100       100
# 14  diagnosticConfirmation  diagnosticConfirmation       94      100       100
# 15                   race2                   race2       94      100       100
# 16  csSiteSpecificFactor15  csSiteSpecificFactor15       18       18        18
# 17                   race3                   race3       94      100       100
# 18                     sex                     sex       94      100       100
# 19       dateOfLastContact       dateOfLastContact       94      100       100
# 20           derivedSs2000           derivedSs2000       18       18        18
# 21              laterality              laterality       94      100       100
# 22                   race1                   race1       94      100       100
# 23   sequenceNumberCentral   sequenceNumberCentral       94      100       100
# 24  csSiteSpecificFactor22  csSiteSpecificFactor22       18       18        18

# %%
IO_TESTING and _obs.where("naaccrId == 'dateOfDiagnosis'").limit(5).toPandas()
# Out:
#                          recordId patientIdNumber         naaccrId  \
# 0          012016-11-130000-00-00        00000103  dateOfDiagnosis
# 1          012015-02-010000-00-00        00000102  dateOfDiagnosis
# 2          012017-11-230000-00-00        00000101  dateOfDiagnosis
# 3          012018-09-110000-00-00        00000100  dateOfDiagnosis
# 4          012017-10-040000-00-00        00000099  dateOfDiagnosis
#
#     concept_cd provider_id  start_date modifier_cd  instance_num valtype_cd  \
# 0  NAACCR|390:           @  2016-11-13           @             1          D
# 1  NAACCR|390:           @  2015-02-01           @             1          D
# 2  NAACCR|390:           @  2017-11-23           @             1          D
# 3  NAACCR|390:           @  2018-09-11           @             1          D
# 4  NAACCR|390:           @  2017-10-04           @             1          D
#
#     tval_char nval_num valueflag_cd units_cd    end_date location_cd  \
# 0  2016-11-13     None         None     None  2016-11-13           @
# 1  2015-02-01     None         None     None  2015-02-01           @
# 2  2017-11-23     None         None     None  2017-11-23           @
# 3  2018-09-11     None         None     None  2018-09-11           @
# 4  2017-10-04     None         None     None  2017-10-04           @
#
#   update_date
# 0  2016-11-13
# 1  2015-02-01
# 2  2017-11-23
# 3  2018-09-11
# 4  2017-10-04

# %% [markdown]
# #### TODO: Code labels; e.g. 1 = Male; 2 = Female

# %%
def pivot_obs_by_enc(skinny_obs: DataFrame,
                     pivot_on: str = 'naaccrId',  # cheating... not really in i2b2 observation_fact
                     # TODO: nval_num etc. for value cols?
                     value_col: str = 'concept_cd',
                     key_cols: List[str] = ['recordId', 'patientIdNumber']) -> DataFrame:
    groups = skinny_obs.select(pivot_on, value_col, *key_cols).groupBy(*key_cols)
    wide = groups.pivot(pivot_on).agg(func.first(value_col))
    return wide


IO_TESTING and pivot_obs_by_enc(_obs.where(
    _obs.naaccrId.isin(['dateOfDiagnosis', 'primarySite', 'sex', 'dateOfBirth'])
)).limit(5).toPandas().set_index(['recordId', 'patientIdNumber'])
# Out:
#                                                dateOfDiagnosis  \
# recordId                       patientIdNumber
#         012015-08-240000-00-00 00000075            NAACCR|390:
#         012015-12-210000-00-00 00000036            NAACCR|390:
#         012018-11-110000-00-00 00000080            NAACCR|390:
#         012015-05-240000-00-00 00000035            NAACCR|390:
#         012018-12-220000-00-00 00000091            NAACCR|390:
#
#                                                     primarySite           sex
# recordId                       patientIdNumber
#         012015-08-240000-00-00 00000075         NAACCR|400:C341  NAACCR|220:1
#         012015-12-210000-00-00 00000036         NAACCR|400:C809  NAACCR|220:1
#         012018-11-110000-00-00 00000080         NAACCR|400:C160  NAACCR|220:1
#         012015-05-240000-00-00 00000035         NAACCR|400:C779  NAACCR|220:2
#         012018-12-220000-00-00 00000091         NAACCR|400:C509  NAACCR|220:2
